# %%
10+20
# Out:
# 30

# %%
print('Hello world')
# Out:
# Hello world

# %%
print('Hello world1')
print('Hello world2')
print('Hello world3')
print('Hello world4')
# Out:
# Hello world1
# Hello world2
# Hello world3
# Hello world4

# %% [markdown]
# # 1. 큰글씨
# ## 2. 큰글씨
# ### 3. 큰글씨
# #### 4.큰글씨
# ##### 5.큰글씨
# ###### 6.큰글씨
# ####### 7.큰글씨
#
# 1. 아래는 hello world를 출력하는 코드입니당~!
# 2. 실행해보세요
# * 목록1
# * 목록2

# %%
print('Hello world')
# Out:
# Hello world

# %%
a=3
print(a)
a=4
print(a)
# Out:
# 3
# 4

# %%
print("Hello World")
print('Python is fun')
print("""Life is too short, You need python""")
print('''Life is too short, You need python''')
# Out:
# Hello World
# Python is fun
# Life is too short, You need python
# Life is too short, You need python

# %% [markdown]
# # 1. 변수
# * 영문 문자와 숫자를 사용할 수 있습니다.
# * 대소문자를 구분합니다.
# * 문자부터 시작해야 하며 숫자로 시작하면 안됨
# * _(under_bar)로 시작할 수 있음
# * 특수문자(+, -, *, $..)은 변수로 사용할 수 없음
# * 파이썬 예약어 (if, form while, and, or) 등은 변수이름으로 사용할 수 없음

# %%
a=3
A=4
print(a)
print(A)
# Out:
# 3
# 4

# %%
a!=8
# Out:
# False

# %%
# a를 변수에 넣어준다
a=8
# a를 출력해주는 코드다
print(a) #출력하는 코드
# print(A)
# 단축키 : ctrl + /
# Out:
# 8

# %%
#예약어는 변수로 사용할 수 없음
# if = 1 # 오류 발생
# print (if)

# %%
import keyword
python_keyword=keyword.kwlist
print(python_keyword)
len(python_keyword)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']
# 35

# %%
# id는 주소값을 나타내는 함수
var1="Hello python"
print(var1)
print(id(var1)) #변수의 메모리 주소
# Out:
# Hello python
# 139995282836848

# %%
var1=100
print(var1)
print(id(var1))
# Out:
# 100
# 9796256

# %%
var2=150.25
print(var2)
print(id(var2))
# Out:
# 150.25
# 139995012750608

# %% [markdown]
# *print() 함수의 다양한 사용

# %%
#출력 print(value1, value2...)
print("Hello world") # 문자열 공백도 글자로 인식
print('Hello','world')
# Out:
# Hello world
# Hello world

# %%
print('홍길동','김철수',sep=',') #출력할때 쉼표로 구분해라
print('홍길동','김철수',sep='/') #출력할때 /로 구분해라
# Out:
# 홍길동,김철수
# 홍길동/김철수

# %%
print('1+1=',1+1)
print('1+1',1+1,sep='=')
# Out:
# 1+1= 2
# 1+1=2

# %%
food="python's favorate food is perl"
food1='python\'s favorate food is perl' # 따옴표 앞에 \버튼 사용으로 따옴표 사용 가능
print(food)
print(food1)
# Out:
# python's favorate food is perl
# python's favorate food is perl

# %%
say='python is very easy. he says'
say1='"python is very easy". he says'
say2="\"python is very easy\". he says"
print(say)
print(say1)
print(say2)
# Out:
# python is very easy. he says
# "python is very easy". he says
# "python is very easy". he says

# %%
# type()
var3="Hello python"
print(var3)
print(type(var3))
#str = string = 문자열
# Out:
# Hello python
# <class 'str'>

# %%
var4=100
print(var4)
print(type(var4)) #int=integer=정수
# Out:
# 100
# <class 'int'>

# %%
var5=150.3
print(var5)
print(type(var5)) #float=실수
# Out:
# 150.3
# <class 'float'>

# %%
var6=True
print(var6)
print(type(var6)) #boolean = 참 또는 거짓
# Out:
# True
# <class 'bool'>

# %% [markdown]
# 자료형 변환

# %%
a=int(10.5) #반올림 하지 않는 정수
print(a)
print(type(a))
# Out:
# 10
# <class 'int'>

# %%
b=float(20)
print(b)
print(type(b))
# Out:
# 20.0
# <class 'float'>

# %%
print(type(True))
print(int(true))
# Out:
# <class 'bool'>

# %%
print(type(True))
print(int(True))
print(int(False))
# Out:
# <class 'bool'>
# 1
# 0

# %%
st="python"
print(type(st))
#print(int(st)) #문자열을 int로 바꾸면 에러
# Out:
# <class 'str'>

# %%
st1 ='10.5' #2번 형변환은 안됨
print(type(st1))
st2=float(st1)
print(int(st2))
print(int(float(st1)))
# Out:
# <class 'str'>
# 10

# %%
c=100.22
print(type(str(c)))
# Out:
# <class 'str'>

# %% [markdown]
# #연산자

# %%
'''연산자(operator)
1. 산술연산자
2. 관계연산자
3. 논리연산자
4. 대입연산자
'''
# Out:
# 연산자(operator)
# 1. 산술연산자
# 2. 관계연산자
# 3. 논리연산자
# 4. 대입연산자

# %%
a='''연산자(operator)
1. 산술연산자
2. 관계연산자
3. 논리연산자
4. 대입연산자
'''
print(a)
# Out:
# 연산자(operator)
# 1. 산술연산자
# 2. 관계연산자
# 3. 논리연산자
# 4. 대입연산자

# %%
#1.산술연산자
num1=100
num2=20
add1= num1+num2
print(add1)
print(type(add1))
# Out:
# 120
# <class 'int'>

# %%
sub=num1-num2
print(sub)
# Out:
# 80

# %%
mul=num1*num2
print(mul)
# Out:
# 2000

# %%
div=num1/num2 #몫을 실수로 반환
print(div)
# Out:
# 5.0

# %%
div1=num1//num2 # 몫을 정수만 반환
print(div1)
# Out:
# 5

# %%
num3=7
num4=4
div2=num3%num4 # 나머지
print(div2)
# Out:
# 3

# %%
sq=num4**3
sq2=num3**2
print(sq)
print(sq2)
# Out:
# 64
# 49

# %% [markdown]
# #관계연산자

# %%
#(1) 동등 비교
bool_result=num1==num2
print(bool_result)
# Out:
# False

# %%
bool_result2=num1!=num2
print(bool_result2)
# Out:
# True

# %%
#(2)크기비교
bool_result3=num1>num2
print(bool_result3)
# Out:
# True

# %%
#문제 1 - 화면에 Hello World 문자열 출력
print("Hello World")
#문제 2 - 화면에 Mary's cosmetics 출력
print("Mary's cosmetics")
#문제 3 - 화면에 C:\Windows 출력
print('C:\Windows')
#문제 4 - print("안녕하세요.\n만나서\t\t반갑습니다.")
# \n 줄바꿈, \t 탭 띄어쓰기 (한번에 4칸 띄는 것)

#문제 5
시가총액 = 298000000000000
현재가=50000
per=15.79

print(시가총액, type(시가총액))
print(현재가, type(현재가))
print(per, type(per))

#문제6
월=48584
할부=36
총금액=월*할부
print(총금액)
# Out:
# Hello World
# Mary's cosmetics
# C:\Windows
# 298000000000000 <class 'int'>
# 50000 <class 'int'>
# 15.79 <class 'float'>
# 1749024

# %% [markdown]
# #논리연산자

# %%
#and 조건
num1=100
num2=20
log_result=num1>=50 and num2<=10 # 참 거짓 # 거짓 반환
print(log_result)

log_result2=num1<=50 and num2>=10 # 거짓 참 # 거짓 반환
print(log_result2)

log_result3=num1>=50 and num2>=10 # 참 참 #and : 둘 다 참이어야만 참을 반환
print(log_result3)

log_result4=num1<=50 and num2<=10 # 거짓 거짓 #and : 둘 다 참이어야만 참을 반환
print(log_result4)
# Out:
# False
# False
# True
# False

# %%
# or 조건

num1=100
num2=20
log_result5=num1>=50 or num2<=10 # 참 거짓 # 참 반환
print(log_result5)

log_result6=num1<=50 or num2>=10 # 거짓 참 # 참 반환
print(log_result6)

log_result7=num1>=50 or num2>=10 # 참 참 # 참 반환
print(log_result3)

log_result8=num1<=50 or num2<=10 # 거짓 거짓 #and : 둘 다 거짓이어야만 거짓을 반환
print(log_result4)
# Out:
# True
# True
# True
# False

# %%
log_result9=not(num1<=50) #not(true) -> 거짓 반환
print(log_result9)
# Out:
# True

# %% [markdown]
# #대입연산자

# %%
# 1) 변수에 값을 할당 (=)
i=tot=10
print(i, tot)
# Out:
# 10 10

# %%
# !python --version
# Out:
# Python 3.8.10

# %%
tot1=10
i1=tot1
print(i1, tot1)
# Out:
# 10 10

# %%
i=i+1
print(i)
# Out:
# 11

# %%
i+=1
print(i)
# Out:
# 12

# %%
tot+=i# tot = tot+i
print(tot) #22
# Out:
# 34

# %%
v1, v2 = 100, 200
print(v1)
print(v2)
# Out:
# 100
# 200

# %%
v1, v2 = v2, v1
print(v1) # 200
print(v2) # 100
# Out:
# 200
# 100

# %%
x=y=z=10
print(x,y,z)
# Out:
# 10 10 10

# %%
del z # delete

# %%
print(x,y)
# Out:
# 10 10

# %%
#print(z) - 오류 발생 / 변수가 없다

# %% [markdown]
# #표준입력장치

# %%
num=input() #표준입력장치는 문자로 형변환됨
print(num)

# %%
print(type(num))
# Out:
# <class 'str'>

# %%
num2=int(input()) #표준입력장치는 문자로 형변환됨
print(num2)
print(type(num2))
# Out:
# 1
# 1
# <class 'int'>

# %%
num3=float(input())
print(num3)
print(type(num3))
# Out:
# 2
# 2.0
# <class 'float'>

# %%
num4=int(float(input()))
print(num4)
print(type(num4))
# Out:
# 5.7
# 5
# <class 'int'>

# %%
num5='10.235'
num5=float(num5)
num6=int(num5)
print(num6)
print(type(num6))
# Out:
# 10
# <class 'int'>

# %%
num7=int(input("정수만 입력하세요 : "))
print(num7)
print(type(num7))
# Out:
# 정수만 입력하세요 : 5
# 5
# <class 'int'>

# %%
n1=int(input("정수만:"))
n2=int(input("정수만:"))
print(n1+n2)
# Out:
# 정수만:1
# 정수만:2
# 3

# %% [markdown]
# #표준출력장치

# %%
#format(value, '양식')
help(format)
# Out:
# Help on built-in function format in module builtins:
#
# format(value, format_spec='', /)
#     Return value.__format__(format_spec)
#
#     format_spec defaults to the empty string.
#     See the Format Specification Mini-Language section of help('FORMATTING') for
#     details.

# %% [markdown]
# ##format과 양식문자

# %%
'''
%양식문자
# %s : 문자열
# %c : 한개문자
# %d : 정수
# %f : 실수
# %o : 8진수
# %x : 16진수
%% : %출력 (%를 문자로 인식)
'''
# Out:
# '\n%양식문자\n%s : 문자열\n%c : 한개문자\n%d : 정수\n%f : 실수\n%o : 8진수\n%x : 16진수\n%% : %출력 (%를 문자로 인식)\n'

# %%
print('원주율=',3.14159)
# Out:
# 원주율= 3 14159

# %%
print('원주율=',format(3.14159, "8.2f")) #format(value, '양식')
# Out:
# 원주율=     3.14

# %%
x=3.14159
print(f'원주율={x:.2f}') #8.2f 공백이 생김
# Out:
# 원주율=3.14

# %%
print(f'금액={10000:,}')
# Out:
# 금액=10,000

# %%
print("금액=",format(10000, "10,d"))
# Out:
# 금액=     10,000

# %%
print("금액=",format(100000000000000, "3,d"))
# Out:
# 금액= 100,000,000,000,000

# %%
# 3) 외부상수받기
name = "홍길동"
age=25
tall=175.456
print('이름: ', name)
print('이름: %s, 나이: %d, data= %.2f'%(name, age, tall))
# Out:
# 이름:  홍길동
# 이름: 홍길동, 나이: 25, data= 175.46

# %%
print('이름:{}, 나이:{}, data : {}'.format(name, age, tall))
# Out:
# 이름:홍길동, 나이:25, data : 175.456

# %%
#축약형 f-string
print(f'이름:{name}, 나이:{age}, data:{tall}')
# Out:
# 이름:홍길동, 나이:25, data:175.456

# %% [markdown]
# 참고사항

# %%
# 변수를 만들때 3가지 방법
# camel 표기법, snake 표기법, pascal 표기법
camelCase=1 #언더바 대신 뒷 명사에 대문자
snake_case=1 #언더바 이용
PascalCase=1 #명사마다 대문자

# %%
multiline="Life is too short \n You need python"
print(multiline)
# Out:
# Life is too short
#  You need python

# %%
multiline2='''
여러줄의
문장을
한번에 포함 시킬 수 있음
'''
print(multiline2)
# Out:
# 여러줄의
# 문장을
# 한번에 포함 시킬 수 있음

# %%
head='python'
tail="  is fun!"
print(head+tail)
print(head*3) #문자와 문자의 곱하기는 안됨
# Out:
# python  is fun!
# pythonpythonpython

# %%
a= "Life is too short, You need python"
print(a[3])
print(a[12])
print(a[-1])
print(a[-5])
# Out:
# e
# s
# n
# y

# %%
a= "Life is too short, You need python"
print(a[5:-1]) #6번째부터 마지막 글자 전까지
print(a[5:-1:2]) #6번째부터 마지막 글자 전까지 첫번째부터 한칸씩 띈 것들만
# Out:
# is too short, You need pytho
# i o hr,Yune yh

# %%
a[0:3] #n-1
a[-5]
# Out:
# 'R'

# %%
# a[처음:끝번호(n-1):간격]

# %%
a='20230307Rainy'
date=a[0:8]
weather=a[8:] #마지막까지 출력하려면 생략해야함
print(date)
print(weather)
# Out:
# 20230307
# Rainy

# %%
#음수만 슬라이싱
b="Hello world"
print(b[:5]) #Hello
print(b[6:]) #world

print(b[:-6]) #print(b[-11:-6]
print(b[-5:]) #world
# Out:
# Hello
# world
# Hello
# world

# %%
#역순으로
print(b[::-1]) #간격이 -1 역순으로
# Out:
# dlrow olleH

# %%
a='hobby'
a.count('b')
# Out:
# 2

# %%
a='Python is best program'
a.find('b') #열한번째
# Out:
# 10

# %%
a.find('k') #해당 문자가 없다면 -1 반환
# Out:
# -1

# %%
a.index('b')
# Out:
# 10

# %%
#a.index('k') #해당 문자가 없다면 오류를 반환

# %%
','.join('abcdefg') #문자열 ''을 구성하는 요소 문자를 구분자로 결합시킨다
#'/'.join('abcdefg')
#' '.join('abcdefg')
# Out:
# 'a,b,c,d,e,f,g'

# %%
g=','
g.join('abcdef')
# Out:
# 'a,b,c,d,e,f'

# %%
a='Python is best program'
print(a.upper()) # 대문자로 전체 바꿈
print(a.lower()) # 소문자로 전체 바꿈
# Out:
# PYTHON IS BEST PROGRAM
# python is best program

# %%
a="      Hi       "
print(a.strip()) #전체 공백
print(a.lstrip()) #왼쪽 공백 (가운데에 있는 공백은 안없어짐))
print(a.rstrip()) #오른쪽 공백 (사이에 공백이 더 있으면 그 공백은 안없어짐)
# Out:
# Hi   s
# Hi   s
#       Hi   s

# %%
a='Java is best program'
b=a.replace('Java','Python')
print(a)
print(b)
# Out:
# Java is best program
# Python is best program

# %%
a='Java is best program'
print(a.split()) #괄호 안에 구분자를 넣어 구분자를 기준으로 문자열을 분리시킴

a='a:b:c:d'
a.split(':')
# Out:
# ['Java', 'is', 'best', 'program']
# ['a', 'b', 'c', 'd']

# %%
phone='010-1234-5678'
phone.split('-')
# Out:
# ['010', '1234', '5678']

# %%
email='abcd@naver.com'
email.split('@')
# Out:
# ['abcd', 'naver.com']

# %% [markdown]
# 퀴즈

# %%
#1. 결과값이 ['naver','com'] 
email='abcd@naver.com'
a1=email.split('@')[1]
b1=a1.split('.')
print(b1)

#2. letter='python'
# p t
letter='python'
print(letter[0],letter[2])



#3. string = "홀짝홀짝홀짝"
#홀홀홀
string = "홀짝홀짝홀짝"
print(string[::2])

#4. 표준입력장치로 사용자의 영문이름을 입력받아서 성과 이름 순서를 바꾸어 출력하는 프로그램을 작성
# 'hong gildong' 
# gildong hong
first_name=input("성을 입력하세요 :")
last_name=input("이름을 입력하세요 :")
print(last_name,first_name)
# Out:
# ['naver', 'com']
# p t
# 홀홀홀
# 성을 입력하세요 :hong
# 이름을 입력하세요 :gildong
# gildong hong

# %%
#4 답_1
full_name = input('영문이름입력(성과 이름은 공백으로 구분) :')
first_name1=full_name.split()[0]
last_name1=full_name.split()[1]
print(last_name1,first_name1)
# Out:
# 영문이름입력(성과 이름은 공백으로 구분) :hong gildong
# gildong hong

# %%
#4 답_2
space=full_name.find(' ')
print(space)

first_name2=full_name[:space]
last_name2=full_name[space+1:]

print(last_name2,first_name2)
# Out:
# 4
# gildong hong

# %%
#4 답_3
full_name.capitalize()
# Out:
# 'Hong gildong'

# %% [markdown]
# #이스케이프문자

# %%
print('escape 문자 차단')
#경로
print('path=','c:\python38\test') #\t 탭 기능으로 인식
print('path=','c:\\python38\\test') #\\ 두개 입력
print('path=',r'c:\python38\test\naver') #문자 앞에 r을 입력
# Out:
# escape 문자 차단
# path= c:\python38	est
# path= c:\python38\test
# path= c:\python38\test\naver

# %%
#1. 신씨가 소리질렀다. "도둑이야"
print('신씨가 소리질렀다. "도둑이야"')
print("신씨가 소리질렀다. \"도둑이야\"")

#2. c\windows\naver\test
print('c\\windows\\naver\\test')
print(r'c\windows\naver\test') #raw

#3. naver/kakao/sk/samsung
print("naver", "kakao", "sk", "samsung", sep="/")

#4.station='신촌',door='왼쪽'
#이번역은 신촌역입니다. 내리실문은 왼쪽입니다.
station='신촌'
door='왼쪽'
#print("이번역은",station,"역입니다. 내리실문은",door,"입니다.")
print(f'이번역은 {station}역입니다. 내리실문은 {door}입니다.')
print("이번역은 "+ station + "역입니다. 내리실문은 "+ door+"입니다.")
# Out:
# 신씨가 소리질렀다. "도둑이야"
# 신씨가 소리질렀다. "도둑이야"
# c\windows\naver\test
# c\windows\naver\test
# naver/kakao/sk/samsung
# 이번역은 신촌역입니다. 내리실문은 왼쪽입니다.
# 이번역은 신촌역입니다. 내리실문은 왼쪽입니다.
