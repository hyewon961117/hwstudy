# %% [markdown]
# # 서울 소방청 리스트 크롤링

# %%
# 소방청 홈페이지
# 기관소개 - 일반현황 - 전국소방기관 안내
# 소방서 위치 검색 (서울)

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re
import time

import selenium
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By

# %%
# 관서명 주소 전화번호
# csv파일로 저장
# kakao api 로 위도 경도 받아오기
# 주소를 못받아오는 곳 있을것
# 못받아오는 경우 인데ㅔㄱ스 확인후 drop
# 페이지를 바꾸는것은 셀레늄으로 바꾸고 난후는 BS로 크롤링

# %%
driver = webdriver.Chrome()
url = "https://www.nfa.go.kr/nfa/introduce/status/firestationidfo/?searchDistance=10&searchMode=distance&myX=37.5382842&myY=126.9213649&searchKeyword="
driver.get(url)
time.sleep(2)

# %%
driver.find_element(By.XPATH,'//*[@id="searchKeyword"]').clear()
driver.find_element(By.XPATH,'//*[@id="searchKeyword"]').send_keys("서울")
driver.find_element(By.XPATH,'//*[@id="fsSearchBtn"]').click()

html = driver.page_source
soup = BeautifulSoup(html, "html.parser")
soup
# Out:
# <html class="sub" lang="ko"><head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0, minimum-scale=1.0" name="viewport"/>
# <title>전국소방기관 안내&lt; 일반현황&lt; 기관소개&lt; 소방청</title>
# <meta content="소방청" name="subject"/>
# <meta content="소방청" name="description"/>
# <meta content="소방청,알림·소식,정보공개,민원,제안,정책자료,기관소개" name="Keywords"/>
# <!-- <link rel="shortcut icon" href="favicon.ico" type="image/x-icon" /> -->
# <link href="/nfa/common/css/font-awesome.min.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/nfa/common/css/jquery.mCustomScrollbar.min.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/nfa/common/css/style.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/nfa/common/css/sub.css" media="all" rel="stylesheet" type="text/css"/>
# ...

# %%
soup.select(".stations-list li")[0].select_one(".title").text.strip()
# Out:
# '동작소방서'

# %%
soup.select(".stations-list li")[0].select_one("address").text.strip()
# Out:
# '서울특별시 동작구 여의대방로16길 55(신대방동)'

# %%
soup.select(".stations-list li")[0].select_one(".tel").text.strip()
# Out:
# '02-847-1190'

# %%
driver.find_element(By.XPATH,'//*[@id="listForm"]/div/section/ul/li[1]/div/div/ul/li[6]/a')
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="d5e5207e6f0ccd293f159967447da86d", element="9adb7541-76a1-435c-8f5c-d28c86e0e342")>

# %%
# 마지막페이지
int(driver.find_element(By.XPATH,'//*[@id="listForm"]/div/section/ul/li[1]/div/div/ul/li[6]/a').get_attribute("href").split("pageIdx=")[1])
# 페이지 주소 가져오기
driver.find_element(By.XPATH,'//*[@id="listForm"]/div/section/ul/li[1]/div/div/ul/li[4]/a').get_attribute("href")
# Out:
# '10'

# %%
#첫번째
driver.find_element(By.XPATH,'//*[@id="listForm"]/div/section/ul/li[1]/div/div/ul/li[3]/a').text

#두번쨰
# driver.find_element(By.XPATH,'//*[@id="listForm"]/div/section/ul/li[1]/div/div/ul/li[4]/a').text
# Out:
# '3'

# %%
# 다음페이지
driver.find_element(By.XPATH,'//*[@id="listForm"]/div/section/ul/li[1]/div/div/ul/li[5]/a').click()

# %%
driver = webdriver.Chrome()
url = "https://www.nfa.go.kr/nfa/introduce/status/firestationidfo/?searchDistance=10&searchMode=distance&myX=37.5382842&myY=126.9213649&searchKeyword="
driver.get(url)
time.sleep(2)

driver.find_element(By.XPATH,'//*[@id="searchKeyword"]').clear()
driver.find_element(By.XPATH,'//*[@id="searchKeyword"]').send_keys("부산")
driver.find_element(By.XPATH,'//*[@id="fsSearchBtn"]').click()
last_num = int(driver.find_element(By.XPATH,'//*[@id="listForm"]/div/section/ul/li[1]/div/div/ul/li[6]/a').get_attribute("href").split("pageIdx=")[1])

lines1 = []
for i in range(1,last_num+1):
    html = driver.page_source
    soup = BeautifulSoup(html, "html.parser")

    for li in soup.select(".stations-list li"):
        관서명 = li.select_one(".title").text.strip()
        주소 = li.select_one("address").text.strip()
        전화번호 = li.select_one(".tel").text.strip()
        lines1.append([관서명, 주소, 전화번호])
            
    if i % 2 == 1:    
        driver.find_element(By.XPATH,'//*[@id="listForm"]/div/section/ul/li[1]/div/div/ul/li[4]/a').click()
        time.sleep(1)
    
    else :
        driver.find_element(By.XPATH,'//*[@id="listForm"]/div/section/ul/li[1]/div/div/ul/li[5]/a').click()
        time.sleep(1)

# %%
lines1
# Out:
# [['정읍소방서-하북-119 안전센터', '전북 정읍시 서부산업도로 507-5', '063-570-1272'],
#  ['남부소방서', '부산광역시 수영구 광일로 64(광안동)', '051-760-4880'],
#  ['동래소방서', '부산광역시 연제구 고분로 216(연산동)', '051-760-4380'],
#  ['북부소방서', '부산광역시 사상구 삼덕로 17(삼락동)', '051-760-4480'],
#  ['중부소방서', '부산광역시 중구 중앙대로 110(중앙동4가)', '051-760-4180'],
#  ['정읍소방서', '전라북도 정읍시 서부산업도로 507-3', '063-570-1251'],
#  ['강서소방서', '부산광역시 강서구 녹산산단361로 9(송정동)', '051-760-5080'],
#  ['항만소방서', '부산광역시 영도구 해양로 297(동삼동)', '051-760-4980'],
#  ['기장소방서', '부산광역시 기장군 정관면 용수로 7', '051-760-5100'],
#  ['부산진소방서', '부산광역시 동구 범일로 115(범일동)', '051-760-4280'],
#  ['해운대소방서', '부산광역시 해운대구 해운대해변로 106(우동)', '051-760-4600'],
#  ['사하소방서', '부산광역시 사하구 장평로 270(신평동)', '051-760-4500'],
#  ['금정소방서', '부산광역시 금정구 중앙대로 1789(부곡동)', '051-760-4780'],
#  ['중부소방서_부산-초량-119 안전센터', '부산광역시 동구 중앙대로 260번길 7-3(초량동)', '051-760-6151'],
#  ['중부소방서_부산-창선-119 안전센터', '부산광역시 중구 대청로 68-1(부평동)', '051-760-6141'],
#  ['중부소방서_부산-충무-119 안전센터', '부산광역시 서구 충무대로 186(남부민동)', '051-760-6131'],
# ...

# %%
len(lines1)
# Out:
# 69

# %% [markdown]
# ## 강사님 방법

# %%
driver = webdriver.Chrome()
url = "https://www.nfa.go.kr/nfa/introduce/status/firestationidfo/?searchDistance=10&searchMode=distance&myX=37.5382842&myY=126.9213649&searchKeyword="
driver.get(url)
time.sleep(2)

# %%
# 입력창에 서울 입력하고 검색 버튼을 누르는 동작
driver.find_element(By.ID, "searchKeyword").send_keys('서울')
driver.find_element(By.ID, "fsSearchBtn").click()

# %%
soup = BeautifulSoup(driver.page_source, "html.parser")
lis = soup.select(".stations-list > li")
li = lis[0]

# %%
li = lis[0]
name = li.select_one(".title").get_text().strip()
addr = li.find('address').get_text().strip()
tel = li.select_one('.tel').get_text().strip()

# %%
name, addr, tel
# Out:
# ('동작소방서', '서울특별시 동작구 여의대방로16길 55(신대방동)', '02-847-1190')

# %%
lines = []
for li in lis:
    name = li.select_one(".title").get_text().strip()
    addr = li.find('address').get_text().strip()
    tel = li.select_one('.tel').get_text().strip()
    lines.append([name, addr, tel])

# %%
lines
# Out:
# [['동작소방서', '서울특별시 동작구 여의대방로16길 55(신대방동)', '02-847-1190'],
#  ['서대문소방서', '서울특별시 서대문구 연희로 182(연희동)', '02-3144-1190'],
#  ['광진소방서', '서울특별시 광진구 광나루로 480(구의동)', '02-457-0119'],
#  ['송파소방서', '서울특별시 송파구 오금로51길 56(마천동)', '02-403-2119'],
#  ['양천소방서', '서울특별시 양천구 목동서로 180(목동)', '02-2655-1119'],
#  ['은평소방서', '서울특별시 은평구 통일로 962(진관동)', '02-355-0119'],
#  ['노원소방서', '서울특별시 노원구 한글비석로 1길 8(하계동)', '02-977-0119'],
#  ['종로소방서', '서울특별시 종로구 종로1길 28(수송동)', '02-735-6119'],
#  ['도봉소방서', '서울특별시 도봉구 도봉로 666(방학동)', '02-3492-3437'],
#  ['용산소방서', '서울특별시 용산구 한강대로 167(한강로2가)', '02-794-0119']]

# %%
# 1페이지에서 다음페이지를 누르면 2페이지가 아님
# 3페이지가 나옴, 그 부분을 if문으로 처리해야함
driver.find_element(By.XPATH,'//*[@id="listForm"]/div/section/ul/li[1]/div/div/ul/li[4]/a').click()
driver.find_element(By.CSS_SELECTOR,'.next_page').click()

# %%
# 검색결과 건수 획득
import math

strong = soup.select('.stations-local-after > p > strong')[1].get_text()
count = int(strong.replace('건','').strip())
count = math.ceil(count/10)
count
# Out:
# 10

# %%
a = 10
math.ceil(a/10)
# Out:
# 1

# %%
driver = webdriver.Chrome()
url = "https://www.nfa.go.kr/nfa/introduce/status/firestationidfo/?searchDistance=10&searchMode=distance&myX=37.5382842&myY=126.9213649&searchKeyword="
driver.get(url)
time.sleep(2)

driver.find_element(By.ID, "searchKeyword").send_keys('서울')
driver.find_element(By.ID, "fsSearchBtn").click()

lines = []
for i in range(count):
    if i >= 1 and i % 2 == 0:
        driver.find_element(By.CSS_SELECTOR,'.next_page').click()
        time.sleep(2)
    if i >= 1 and i % 2 == 1:
        driver.find_element(By.XPATH,'//*[@id="listForm"]/div/section/ul/li[1]/div/div/ul/li[4]/a').click()
        time.sleep(2)
        
    soup = BeautifulSoup(driver.page_source, "html.parser")
    lis = soup.select(".stations-list > li")
    
    for li in lis:
        name = li.select_one(".title").get_text().strip()
        addr = li.find('address').get_text().strip()
        tel = li.select_one('.tel').get_text().strip()
        lines.append([name, addr, tel])

# %%
len(lines)
# Out:
# 100

# %%
driver.close()

# %%
df = pd.DataFrame(lines, columns = ['관서명', '주소','전화번호'])
df.tail()
# Out:
#                    관서명                         주소          전화번호
# 95  송파소방서-운동장-119 안전센터    서울특별시 송파구 올림픽로 25 (잠실동)  02-2203-2380
# 96   송파소방서-잠실-119 안전센터  서울특별시 송파구 석촌호수로 151 (잠실동)   02-422-0119
# 97   송파소방서-방이-119 안전센터   서울특별시 송파구 강동대로 286 (방이동)   02-409-0059
# 98   송파소방서-거여-119 안전센터    서울특별시 송파구 마천로 329 (마천동)   02-400-0119
# 99   송파소방서-마천-119 안전센터  서울특별시 송파구 오금로51길 56 (마천동)  02-3401-2119

# %%
df.to_csv("서울소방서.csv", index=False)

# %% [markdown]
# # 시각화

# %%
import numpy as np
import pandas as pd

import requests
from urllib.parse import quote

import folium, json

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("./서울소방서.csv")

# %%
df
# Out:
#                    관서명                           주소          전화번호
# 0                동작소방서  서울특별시 동작구 여의대방로16길 55(신대방동)   02-847-1190
# 1               서대문소방서      서울특별시 서대문구 연희로 182(연희동)  02-3144-1190
# 2                광진소방서      서울특별시 광진구 광나루로 480(구의동)   02-457-0119
# 3                송파소방서     서울특별시 송파구 오금로51길 56(마천동)   02-403-2119
# 4                양천소방서       서울특별시 양천구 목동서로 180(목동)  02-2655-1119
# ..                 ...                          ...           ...
# 95  송파소방서-운동장-119 안전센터      서울특별시 송파구 올림픽로 25 (잠실동)  02-2203-2380
# 96   송파소방서-잠실-119 안전센터    서울특별시 송파구 석촌호수로 151 (잠실동)   02-422-0119
# 97   송파소방서-방이-119 안전센터     서울특별시 송파구 강동대로 286 (방이동)   02-409-0059
# 98   송파소방서-거여-119 안전센터      서울특별시 송파구 마천로 329 (마천동)   02-400-0119
# 99   송파소방서-마천-119 안전센터    서울특별시 송파구 오금로51길 56 (마천동)  02-3401-2119
#
# [100 rows x 3 columns]

# %%
# KAKAO API로 위, 경도값을 추출
with open('C:/workspace/APIkey/카카오API.txt') as file:
    kakao_key = file.read()

# %%
lat_list = []
lng_list = []

for i in df.index :
    search_url = "https://dapi.kakao.com/v2/local/search/address.json"
    url = f'{search_url}?query={quote(df["주소"][i])}'
    result = requests.get(url, 
                          headers={"Authorization": f'KakaoAK {kakao_key}'}).json()
    try : 
        lng_list.append(float(result['documents'][0]['x']))
        lat_list.append(float(result['documents'][0]['y']))
    except : 
        print(df['관서명'][i])
# Out:
# 은평소방서-수색-119 안전센터

# %%
df[df.관서명.isin(['은평소방서-수색-119 안전센터'])].주소
# Out:
# 30    서울특별시 은평구 수색로 294 (수색동)
# Name: 주소, dtype: object

# %%
df.drop(30, axis=0, inplace=True)

# %%
len(df)
# Out:
# 99

# %%
# 지우고 다시 돌려주기
lat_list = []
lng_list = []

for i in df.index :
    search_url = "https://dapi.kakao.com/v2/local/search/address.json"
    url = f'{search_url}?query={quote(df["주소"][i])}'
    result = requests.get(url, 
                          headers={"Authorization": f'KakaoAK {kakao_key}'}).json()
    try : 
        lng_list.append(float(result['documents'][0]['x']))
        lat_list.append(float(result['documents'][0]['y']))
    except : 
        print(df['관서명'][i])

# %%
df['위도'] = lat_list
df['경도'] = lng_list

# %%
# 만약 추가하고 싶다면
url = f'{search_url}?query={quote("서울특별시 은평구 수색로 320")}'
result = requests.get(url, 
                      headers={"Authorization": f'KakaoAK {kakao_key}'}).json()
print(float(result['documents'][0]['x']))
print(float(result['documents'][0]['y']))
# Out:
# 126.889905679045
# 37.5852677029786

# %%
map = folium.Map(location=[37.5502, 126.982], zoom_start=12)
for i in df.index:
    folium.Marker(location = [df.위도[i], df.경도[i]],
                 popup=folium.Popup(df.주소[i], max_width=200),
                 tooltip=f'{df.관서명[i]}',
                 icon = folium.Icon(icon = 'glyphicon glyphicon-home')).add_to(map)
title_html = '<h3 align="center", style="font-size:20px"> 서울소재 소방서 위치 </h3>'      
map.get_root().html.add_child(folium.Element(title_html))
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
