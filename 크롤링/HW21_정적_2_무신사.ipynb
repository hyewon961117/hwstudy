# %% [markdown]
# # 실제 사이트 _ 무신사

# %%
import requests
from bs4 import BeautifulSoup
import re # 정규표현식 사용을 위한 패키지

# %%
for i in range(1,3):
    print('PAGE ====================', i)
    url = f'https://www.musinsa.com/categories/item/001?d_cat_cd=001&brand=&list_kind=small&sort=pop_category&sub_sort=&page={i}&display_cnt=90&group_sale=&exclusive_yn=&sale_goods=&timesale_yn=&ex_soldout=&kids=&color=&price1=&price2=&shoeSizeOption=&tags=&campaign_id=&includeKeywords=&measure='
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
#     print(soup)
    for item in soup.select("ul#searchList>li"):
        print('상품명:', item.select_one(".article_info p.list_info a").attrs['title'])
        print('브랜드:', item.select_one(".article_info p.item_title").text.strip())
        price =""
        
        # 원래 가격과 세일가격 2개가 있는 경우가 있기 때문에 길이를 1또는 else로 처리
        if len(item.select_one('.article_info p.price').text.strip().split(" ")) == 1:
            price = item.select_one('.article_info p.price').text.strip().split(" ")[0]
        else:
            price = item.select_one('.article_info p.price').text.strip().split(" ")[16]
        print('가격: ', price)
        print("")
# Out:
# PAGE ==================== 1
# 상품명: 레이어드 크루 넥 반팔 티셔츠_일반 기장 [화이트]
# 브랜드: 무신사 스탠다드
# 가격:  16,900원
#
# 상품명: 베이식 긴팔 티셔츠 2팩
# 브랜드: 무신사 스탠다드
# 가격:  37,800원
#
# 상품명: [무료반품] 워셔블 하찌 니트 - 11 COLOR
# 브랜드: 수아레
# 가격:  39,900원
#
# 상품명: 레이어드 크루 넥 반팔 티셔츠_긴 기장 [화이트]
# 브랜드: 무신사 스탠다드
# 가격:  16,900원
#
# 상품명: [2PACK] 베이식 무지 레이어드 반팔 티셔츠 일반 기장...
# 브랜드: 프린트스타
# 가격:  16,900원
#
# 상품명: 레이어드 크루 넥 반팔 티셔츠_일반 기장 2팩
# 브랜드: 무신사 스탠다드
# 가격:  33,800원
#
# 상품명: 릴렉스 핏 크루 넥 반팔 티셔츠 [화이트]
# 브랜드: 무신사 스탠다드
# 가격:  15,900원
#
# 상품명: [깡스타일리스트 PICK] (시티보이) 오버핏 옥스포드 셔...
# 브랜드: 스파오
# 가격:  35,910원
#
# 상품명: 에센셜 후드 스웻 셔츠 (MELANGE GREY)
# 브랜드: 토피
# 가격:  39,000원
#
# 상품명: [패키지 상품] Longsleeve 무지 긴팔티
# 브랜드: 브렌슨
# 가격:  29,900원
#
# 상품명: 베이식 긴팔 티셔츠 [화이트]
# 브랜드: 무신사 스탠다드
# 가격:  18,900원
#
# 상품명: 980g pigment mtm-charcoal-
# 브랜드: 소버먼트
# 가격:  49,200원
#
# 상품명: 코튼 워셔블 하찌 하프집업 니트_5 COLOR
# 브랜드: 키뮤어
# 가격:  42,900원
#
# 상품명: [SS Ver.]헤비 코튼 오버 럭비 맨투맨_Midnigh...
# 브랜드: 라퍼지스토어
# 가격:  36,000원
#
# 상품명: 베이식 크루 넥 반팔 티셔츠 [화이트]
# 브랜드: 무신사 스탠다드
# 가격:  13,900원
#
# 상품명: [무료반품] 화란 세미오버 니트 블랙
# 브랜드: 엘무드
# 가격:  61,600원
#
# 상품명: LEISURE TIME LOGO SWEATSHIRT NAV...
# 브랜드: 아메스 월드와이드
# 가격:  44,800원
#
# 상품명: [무료반품] [리뉴얼] 하프 터틀넥 니트 세트
# 브랜드: 수아레
# 가격:  39,900원
#
# 상품명: (23SS) 2 TONE ARCH HOODIE GRAY
# 브랜드: 예일
# 가격:  55,300원
#
# 상품명: DON’T PANIC PIGMENT SWEATSHIRT P...
# 브랜드: 마하그리드
# 가격:  51,800원
#
# 상품명: 스웨트셔츠 [블랙]
# 브랜드: 무신사 스탠다드
# 가격:  29,900원
#
# 상품명: 에센셜 쿨 코튼 2-PACK 티셔츠 블랙
# 브랜드: 커버낫
# 가격:  44,100원
#
# 상품명: 우먼즈 베이식 크루 넥 반팔 티셔츠 [화이트]
# 브랜드: 무신사 스탠다드
# 가격:  13,900원
#
# 상품명: 워셔블 하프 집업 카라넥 하찌 니트 (PURE BLACK)...
# 브랜드: 트릴리온
# 가격:  39,800원
#
# 상품명: [SET] (맨투맨 OR 후드 선택) CGP 아치 로고 트...
# 브랜드: 코드그라피
# 가격:  72,900원
#
# 상품명: 카라 케이블 니트 집업 블랙
# 브랜드: 굿라이프웍스
# 가격:  63,000원
#
# 상품명: SIGN LOGO HOOD GRAY
# 브랜드: 와릿이즌
# 가격:  31,050원
#
# 상품명: 릴렉스 핏 크루 넥 반팔 티셔츠 [블랙]
# 브랜드: 무신사 스탠다드
# 가격:  15,900원
#
# 상품명: 로그 오버핏 기모 후드 그레이 YHHD2302
# 브랜드: 제멋
# 가격:  34,900원
#
# 상품명: [3-PACK]베이직 트래블러 피그먼트 스웨트셔츠
# 브랜드: 트래블
# 가격:  59,900원
#
# 상품명: [세트]  하프 폴라 니트 티셔츠
# 브랜드: 이에스엔
# 가격:  35,100원
#
# 상품명: SIGN LOGO HOOD BLACK
# 브랜드: 와릿이즌
# 가격:  31,050원
#
# 상품명: 고밀도순면기본반팔티셔츠_3팩 MATS0101
# 브랜드: 마인드브릿지
# 가격:  19,900원
#
# 상품명: 릴렉스 핏 옥스포드 셔츠 [화이트]
# 브랜드: 무신사 스탠다드
# 가격:  33,900원
#
# 상품명: 램스울 크루넥 오버니트(연차콜)
# 브랜드: 테이크이지
# 가격:  37,800원
#
# 상품명: 하이 벤트 레이어드 티셔츠 [WHITE]
# 브랜드: 드로우핏
# 가격:  29,250원
#
# 상품명: 릴렉스 핏 크루 넥 반팔 티셔츠 2팩
# 브랜드: 무신사 스탠다드
# 가격:  31,800원
#
# 상품명: 베이식 긴팔 티셔츠 [블랙]
# 브랜드: 무신사 스탠다드
# 가격:  18,900원
#
# 상품명: 크루넥 리브 니트 스웨터_블랙
# 브랜드: 블론드나인
# 가격:  28,800원
#
# 상품명: 베이식 크루 넥 반팔 티셔츠 2팩
# 브랜드: 무신사 스탠다드
# 가격:  27,800원
#
# 상품명: 크래킹 스냅 레글런 후드티 블랙
# 브랜드: 꼼파뇨
# 가격:  59,800원
#
# 상품명: 오버핏 아치 로고 스웨트 셔츠-그린
# 브랜드: 필루미네이트
# 가격:  39,900원
#
# 상품명: 램스울 크루넥 오버니트(블랙)
# 브랜드: 테이크이지
# 가격:  37,800원
#
# 상품명: 오버사이즈 집업 카라 터틀넥 니트 [M.GREY]
# 브랜드: 드로우핏
# 가격:  68,400원
#
# 상품명: [드로우핏X깡스타일리스트] 모크넥 니트 티셔츠 SET
# 브랜드: 드로우핏
# 가격:  43,900원
#
# 상품명: (23SS) 2 TONE ARCH TEE WHITE
# 브랜드: 예일
# 가격:  35,100원
#
# 상품명: [SET] (맨투맨 OR 후드 선택) CGP 아치 로고 트...
# 브랜드: 코드그라피
# 가격:  72,900원
#
# 상품명: [블랙]SET B-스테디 하프 폴라넥
# 브랜드: 필루미네이트
# 가격:  29,900원
#
# 상품명: RALLY COLLARED SWEATSHIRT NAVY(M...
# 브랜드: 마하그리드
# 가격:  66,600원
#
# 상품명: 컬러 배색 1992 그래픽 후드 (NAVY)
# 브랜드: 트릴리온
# 가격:  39,800원
#
# 상품명: [무료반품] 트위드 크루넥 니트웨어_레몬블랙
# 브랜드: 인템포무드
# 가격:  58,700원
#
# 상품명: 021541 레이어드 반팔 티셔츠(2pck)
# 브랜드: 지오다노
# 가격:  16,800원
#
# 상품명: LAUNDRY SHIRT (LAVENDER GRAY)
# 브랜드: 유니온블루
# 가격:  59,000원
#
# 상품명: [기모] Geppetto 자수 후드 크림
# 브랜드: 꼼파뇨
# 가격:  46,800원
#
# 상품명: [무료반품] [니티드X깡스타일리스트] 코튼 미니멀 라운드 ...
# 브랜드: 니티드
# 가격:  59,400원
#
# 상품명: PHYPS® STRAWBERRY HOODIE OATMEAL...
# 브랜드: 피지컬 에듀케이션 디파트먼트
# 가격:  57,400원
#
# 상품명: 피치스킨 벌룬오버 후드 - 블랙
# 브랜드: 엠오오
# 가격:  49,600원
#
# 상품명: 쿨 코튼 2-PACK 티셔츠 화이트
# 브랜드: 커버낫
# 가격:  34,400원
#
# 상품명: (솔리드 OR 멀티트위드 선택)_12컬러 코튼 워셔블 하찌...
# 브랜드: 키뮤어
# 가격:  39,900원
#
# 상품명: (23SS) (YALE HEAVYWEIGHT) MIXED ...
# 브랜드: 예일
# 가격:  62,300원
#
# 상품명: 워셔블 하프 집업 카라넥 하찌 니트 (CURRENT NAV...
# 브랜드: 트릴리온
# 가격:  39,800원
#
# 상품명: 에센셜 후드 스웻 셔츠 (BLACK)
# 브랜드: 토피
# 가격:  39,000원
#
# 상품명: SMALL SIGN LOGO SWEATSHIRT BLACK...
# 브랜드: 와릿이즌
# 가격:  23,600원
#
# 상품명: 950g solid hoody-deep black-
# 브랜드: 소버먼트
# 가격:  62,400원
#
# 상품명: 솔리드 케이블 니트 풀오버 투웨이 집업 가디건 카라 자켓
# 브랜드: 플레이스 스튜디오
# 가격:  39,800원
#
# 상품명: 오버핏 아치 로고 스웨트 셔츠-네이비
# 브랜드: 필루미네이트
# 가격:  39,900원
#
# 상품명: 베이식 드레스 셔츠 [화이트]
# 브랜드: 무신사 스탠다드
# 가격:  33,900원
#
# 상품명: [패키지] 더블코튼 무지반팔  패키지 KHST1011
# 브랜드: 페플
# 가격:  29,900원
#
# 상품명: [패키지] 에센셜 레이어드 롱 슬리브 티셔츠
# 브랜드: 트릴리온
# 가격:  39,800원
#
# 상품명: 슬레이크 후드 네이비 HHHD3397
# 브랜드: 티떠블유엔
# 가격:  41,900원
#
# 상품명: 슬레이크 후드 올리브 HHHD3397
# 브랜드: 티떠블유엔
# 가격:  41,900원
#
# 상품명: 폰테 크루 넥 긴팔 티셔츠 [오프 화이트]
# 브랜드: 무신사 스탠다드
# 가격:  21,090원
#
# 상품명: UNISEX LAUREL OVERSIZED HOODIE -...
# 브랜드: 어반드레스
# 가격:  35,880원
#
# 상품명: [호시 착용] [SET] (긴바지 OR 반바지 선택) 24...
# 브랜드: 코드그라피
# 가격:  78,900원
#
# 상품명: (23SS) 2 TONE ARCH HOODIE BLACK
# 브랜드: 예일
# 가격:  55,300원
#
# 상품명: 솔리드 옥스포드 오버셔츠(화이트)
# 브랜드: 테이크이지
# 가격:  40,200원
#
# 상품명: [무료반품] 투톤 사선 라운드 니트 - 퍼플
# 브랜드: 르마드
# 가격:  72,000원
#
# 상품명: (23SS) [ONEMILE WEAR] SMALL ARCH...
# 브랜드: 예일
# 가격:  49,000원
#
# 상품명: [UNISEX] 45수 특양면 옆트임 오버핏 반팔티 (화이...
# 브랜드: 티아즈
# 가격:  14,700원
#
# 상품명: 미시간 울버린 피그먼트 후드티 블랙 차콜
# 브랜드: 트래블
# 가격:  54,900원
#
# 상품명: 레이어드 크루 넥 긴팔 티셔츠_일반 기장 [화이트]
# 브랜드: 무신사 스탠다드
# 가격:  19,900원
#
# 상품명: [무료반품] 브룩 니트 ( 5 COLOR )
# 브랜드: 엘무드
# 가격:  71,900원
#
# 상품명: 헤비웨이트 오버사이즈 스웨트셔츠 [블랙]
# 브랜드: 무신사 스탠다드
# 가격:  31,790원
#
# 상품명: 오버핏 아치 로고 스웨트 셔츠-와인
# 브랜드: 필루미네이트
# 가격:  39,900원
#
# 상품명: [무료반품] 화란 세미오버 니트 크림
# 브랜드: 엘무드
# 가격:  61,600원
#
# 상품명: 램스울 크루넥 오버니트(헤더블루)
# 브랜드: 테이크이지
# 가격:  37,800원
#
# 상품명: LAUNDRY SHIRT (LEMON)
# 브랜드: 유니온블루
# 가격:  59,000원
#
# 상품명: 베이식 크루 넥 반팔 티셔츠 [블랙]
# 브랜드: 무신사 스탠다드
# 가격:  13,900원
#
# 상품명: [2PACK] 7.5oz 헤비웨이트 무지 오버핏 레이어드 ...
# 브랜드: 샤카웨어
# 가격:  32,900원
#
# 상품명: 오버사이즈 집업 카라 터틀넥 니트 [BLACK]
# 브랜드: 드로우핏
# 가격:  68,400원
#
# PAGE ==================== 2
# 상품명: TAG HOODIE - BLACK
# 브랜드: 브라운브레스
# 가격:  63,200원
#
# 상품명: [드로우핏X깡스타일리스트] 터틀넥 니트 티셔츠 SET
# 브랜드: 드로우핏
# 가격:  43,900원
#
# 상품명: TAG HOODIE - ASH
# 브랜드: 브라운브레스
# 가격:  63,200원
#
# 상품명: [일반/기모] LT431_러닝클럽 럭비 맨투맨_네이비
# 브랜드: 어반디타입
# 가격:  36,000원
#
# 상품명: PHYPS® MONDAY ROUTINE STITCH HOO...
# 브랜드: 피지컬 에듀케이션 디파트먼트
# 가격:  55,300원
#
# 상품명: [세트상품] 더블 코튼 롱 티셔츠
# 브랜드: 어커버
# 가격:  25,900원
#
# 상품명: Traveler Oversized Sweater(TEAL ...
# 브랜드: 메인부스
# 가격:  66,700원
#
# 상품명: LAUNDRY SHIRT (WHITE)
# 브랜드: 유니온블루
# 가격:  59,000원
#
# 상품명: [패키지] NYC LOCATION T-SHIRT (16CO...
# 브랜드: 그루브라임
# 가격:  35,000원
#
# 상품명: 솔리드 옥스포드 오버셔츠(스카이블루)
# 브랜드: 테이크이지
# 가격:  40,200원
#
# 상품명: 오버핏 그래피티 로고 후디-멜란지그레이
# 브랜드: 필루미네이트
# 가격:  47,900원
#
# 상품명: 옵티멀 베이직 셔츠-화이트
# 브랜드: 필루미네이트
# 가격:  39,900원
#
# 상품명: 레이어드 크루 넥 반팔 티셔츠_긴 기장 2팩
# 브랜드: 무신사 스탠다드
# 가격:  33,800원
#
# 상품명: [무료반품] 1960 sweatshirts navy
# 브랜드: 유니폼브릿지
# 가격:  65,000원
#
# 상품명: LAUNDRY SHIRT (SKY BLUE)
# 브랜드: 유니온블루
# 가격:  59,000원
#
# 상품명: 램스울 크루넥 오버니트(아이보리)
# 브랜드: 테이크이지
# 가격:  37,800원
#
# 상품명: [패키지] 올카 오버핏 스웨트셔츠 9종 2PACK KJMT...
# 브랜드: 제멋
# 가격:  47,900원
#
# 상품명: 빈티지 반 집업_다크그린
# 브랜드: 1993스튜디오
# 가격:  57,600원
#
# 상품명: [호시 착용] [SET] (긴바지 OR 반바지 선택) 90...
# 브랜드: 코드그라피
# 가격:  75,900원
#
# 상품명: 빅 트위치 로고 티셔츠 화이트
# 브랜드: 리
# 가격:  35,000원
#
# 상품명: 베이식 옥스포드 셔츠 [화이트]
# 브랜드: 무신사 스탠다드
# 가격:  33,900원
#
# 상품명: [23SS Ver.][Package]시티보이 빅오버 옥스포...
# 브랜드: 라퍼지스토어
# 가격:  59,800원
#
# 상품명: DOODLE LOGO HOODIE - BLACK
# 브랜드: 노매뉴얼
# 가격:  87,000원
#
# 상품명: EarthHeart 후드티
# 브랜드: 벤힛
# 가격:  30,900원
#
# 상품명: 쿨코튼 2-PACK 베츠 기본 반팔 티셔츠 블랙/화이트
# 브랜드: 이벳필드
# 가격:  34,300원
#
# 상품명: 90S 트랙 스웨트셔츠_블랙
# 브랜드: 1993스튜디오
# 가격:  85,000원
#
# 상품명: 하프 집업 리브 니트 탑_그레이
# 브랜드: 블론드나인
# 가격:  38,800원
#
# 상품명: SWEATSHIRT FLOWERMARDI_OATMEAL B...
# 브랜드: 마르디 메크르디
# 가격:  71,250원
#
# 상품명: [3PACK] 32수 라이트 코튼 반팔 티셔츠
# 브랜드: 프린트스타
# 가격:  18,900원
#
# 상품명: [패키지] Errday 루즈핏 맨투맨 2`nd
# 브랜드: 브렌슨
# 가격:  45,900원
#
# 상품명: 빅 트위치 루즈핏 후드 네이비
# 브랜드: 리
# 가격:  79,000원
#
# 상품명: [패키지] 베이직 크루넥 반팔티 (오버핏/트임 선택)
# 브랜드: 브렌슨
# 가격:  27,900원
#
# 상품명: 워셔블 하프 집업 카라넥 하찌 니트 (NEUTRAL GRA...
# 브랜드: 트릴리온
# 가격:  39,800원
#
# 상품명: 레이어드 슬리브리스 탑_일반 기장 [화이트]
# 브랜드: 무신사 스탠다드
# 가격:  13,390원
#
# 상품명: Velour Soccer Jersey Black
# 브랜드: 스컬프터
# 가격:  101,150원
#
# 상품명: [드로우핏X깡스타일리스트] 모크넥 니트 티셔츠
# 브랜드: 드로우핏
# 가격:  23,900원
#
# 상품명: 퍼펙트 터틀넥 니트 티셔츠 블랙
# 브랜드: 이에스엔
# 가격:  23,000원
#
# 상품명: 미시간 울버린 피그먼트 반팔티 블랙 차콜
# 브랜드: 트래블
# 가격:  29,900원
#
# 상품명: RESEARCH HOODIE [KHAKI]
# 브랜드: 비바스튜디오
# 가격:  69,800원
#
# 상품명: COLLEGE LOGO HOODIE BLACK(MG2BSM...
# 브랜드: 마하그리드
# 가격:  55,200원
#
# 상품명: 크루넥 리브 니트 스웨터_브라운
# 브랜드: 블론드나인
# 가격:  28,800원
#
# 상품명: SWEATSHIRT FLOWERMARDI BLOSSOM_N...
# 브랜드: 마르디 메크르디
# 가격:  84,550원
#
# 상품명: 피치스킨 러스티 로고 스웨트셔츠 [블랙]
# 브랜드: 슬로우애시드
# 가격:  62,100원
#
# 상품명: 오버핏 그래피티 로고 후디-블랙
# 브랜드: 필루미네이트
# 가격:  47,900원
#
# 상품명: 릴렉스 핏 크루 넥 반팔 티셔츠 2 [화이트]
# 브랜드: 무신사 스탠다드
# 가격:  14,290원
#
# 상품명: 우먼즈 릴렉스드 크루 넥 긴팔 티셔츠 [화이트]
# 브랜드: 무신사 스탠다드
# 가격:  18,900원
#
# 상품명: [쿨탠다드] 릴렉스 핏 크루 넥 반팔 티셔츠 2팩
# 브랜드: 무신사 스탠다드
# 가격:  39,800원
#
# 상품명: 오버핏 아치 로고 스웨트 셔츠-크림
# 브랜드: 필루미네이트
# 가격:  39,900원
#
# 상품명: 미니멀 크루 넥 니트 [블랙]
# 브랜드: 무신사 스탠다드
# 가격:  59,390원
#
# 상품명: 클럽 레플리카 스웻셔츠 [오프 화이트]
# 브랜드: 슈퍼서브
# 가격:  39,000원
#
# 상품명: 폰테 크루 넥 긴팔 티셔츠 [블랙]
# 브랜드: 무신사 스탠다드
# 가격:  22,390원
#
# 상품명: 헤비웨이트 오버사이즈 후디드 스웨트셔츠 [블랙]
# 브랜드: 무신사 스탠다드
# 가격:  49,900원
#
# 상품명: 빈티지 반 집업_오트베이지
# 브랜드: 1993스튜디오
# 가격:  57,600원
#
# 상품명: (23SS) 2 TONE ARCH HOODIE NAVY
# 브랜드: 예일
# 가격:  55,300원
#
# 상품명: 에센셜 후드 스웻 셔츠 (CHARCOAL)
# 브랜드: 토피
# 가격:  39,000원
#
# 상품명: 하이 벤트 레이어드 티셔츠 [BLACK]
# 브랜드: 드로우핏
# 가격:  29,250원
#
# 상품명: 오버핏 아치 로고 스웨트 셔츠-블랙
# 브랜드: 필루미네이트
# 가격:  39,900원
#
# 상품명: [무료반품] 트위드 크루넥 니트웨어_아이스블루
# 브랜드: 인템포무드
# 가격:  58,700원
#
# 상품명: TC5-SH08 프렌치 스트라이프 셔츠-네이비
# 브랜드: 토마스모어
# 가격:  56,715원
#
# 상품명: 아치 팬시 로고 후드티_화이트메란지
# 브랜드: 어나더 아카이브
# 가격:  35,800원
#
# 상품명: 캠프 바시티 피그먼트 스웨트셔츠 블루 섀도우
# 브랜드: 트래블
# 가격:  49,900원
#
# 상품명: 빈티지 반 집업_라이트그레이
# 브랜드: 1993스튜디오
# 가격:  50,400원
#
# 상품명: 크루 넥 긴팔 티셔츠 [화이트]
# 브랜드: 무신사 스탠다드
# 가격:  19,900원
#
# 상품명: 로그 오버핏 기모 후드 블랙 YHHD2302
# 브랜드: 제멋
# 가격:  34,900원
#
# 상품명: [SS Ver.]헤비 코튼 오버 럭비 맨투맨_Black
# 브랜드: 라퍼지스토어
# 가격:  36,000원
#
# 상품명: ROUND LOGO CREWNECK SWEATSHIRT B...
# 브랜드: 프렌다
# 가격:  47,200원
#
# 상품명: [레드벨벳 웬디 PICK] [패키지] NYC LOCATIO...
# 브랜드: 그루브라임
# 가격:  69,000원
#
# 상품명: (23SS) [ONEMILE WEAR] SMALL ARCH...
# 브랜드: 예일
# 가격:  49,000원
#
# 상품명: [무료반품] 울 오버핏 라운드 니트 - 오렌지
# 브랜드: 르마드
# 가격:  68,400원
#
# 상품명: 코튼 워셔블 후드니트
# 브랜드: 키뮤어
# 가격:  54,900원
#
# 상품명: [무료반품] [니티드X깡스타일리스트] 코튼 미니멀 라운드 ...
# 브랜드: 니티드
# 가격:  59,400원
#
# 상품명: [논기모]나마스테 스켈레톤 후디_핑크(NG2DSUM403A...
# 브랜드: 나이스고스트클럽
# 가격:  63,200원
#
# 상품명: 크루넥 리브 니트 스웨터_스카이 블루
# 브랜드: 블론드나인
# 가격:  28,800원
#
# 상품명: 크루넥 리브 니트 스웨터_네이비
# 브랜드: 블론드나인
# 가격:  28,800원
#
# 상품명: (23SS) EMBROIDERY UNIVERSITY DAN...
# 브랜드: 예일
# 가격:  55,300원
#
# 상품명: [무료반품] 해비 코튼 썸홀 후디 : 15color
# 브랜드: 인템포무드
# 가격:  73,900원
#
# 상품명: 케이블 카라 니트[그린]
# 브랜드: 시그니처
# 가격:  53,000원
#
# 상품명: 레이어드 크루 넥 반팔 티셔츠_일반 기장 [블랙]
# 브랜드: 무신사 스탠다드
# 가격:  16,900원
#
# 상품명: 베츠 어센틱 맨투맨 그레이
# 브랜드: 이벳필드
# 가격:  27,600원
#
# 상품명: 오버핏 울 체크 셔츠 그레이
# 브랜드: 어반드레스
# 가격:  39,840원
#
# 상품명: 오버핏 그래피티 로고 후디-오트밀
# 브랜드: 필루미네이트
# 가격:  47,900원
#
# 상품명: 크루넥 리브 니트 스웨터_아이보리
# 브랜드: 블론드나인
# 가격:  28,800원
#
# 상품명: (23SS) 2 TONE ARCH TEE ROYAL BLU...
# 브랜드: 예일
# 가격:  35,100원
#
# 상품명: COLLEGE LOGO HOODIE GREY(MG2BSMM...
# 브랜드: 마하그리드
# 가격:  55,200원
#
# 상품명: [3PACK] 베이식 무지 레이어드 반팔 티셔츠 일반 기장...
# 브랜드: 프린트스타
# 가격:  24,500원
#
# 상품명: [23SS Ver.]시티보이 빅오버 옥스포드 셔츠_Roya...
# 브랜드: 라퍼지스토어
# 가격:  36,800원
#
# 상품명: [SET] (맨투맨 OR 후드 선택) CGP 아치 로고 트...
# 브랜드: 코드그라피
# 가격:  72,900원
#
# 상품명: 후디드 스웨트셔츠 [멜란지 그레이]
# 브랜드: 무신사 스탠다드
# 가격:  33,990원
#
# 상품명: [패키지] 로그 오버핏 기모 후드 2Pack YHHD230...
# 브랜드: 제멋
# 가격:  62,500원
#
# 상품명: [드로우핏X깡스타일리스트] 터틀넥 니트 티셔츠
# 브랜드: 드로우핏
# 가격:  23,900원

# %%
for i in range(1,3):
    print('PAGE ====================', i)
    url = f'https://www.musinsa.com/categories/item/001?d_cat_cd=001&brand=&list_kind=small&sort=pop_category&sub_sort=&page={i}&display_cnt=90&group_sale=&exclusive_yn=&sale_goods=&timesale_yn=&ex_soldout=&kids=&color=&price1=&price2=&shoeSizeOption=&tags=&campaign_id=&includeKeywords=&measure='
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
#     print(soup)
    for item in soup.select("ul#searchList>li"):
        print('상품명:', item.select_one(".article_info p.list_info a").attrs['title'])
        print('브랜드:', item.select_one(".article_info p.item_title").text.strip())
        price =""
        
        # 가격 정규표현식 이용 방법
        if len(re.findall('[0-9,]*원', item.select_one('.article_info p.price').text)) == 1:
            price = re.findall('[0-9,]*원', item.select_one('.article_info p.price').text)[0]
        else:
            price = re.findall('[0-9,]*원', item.select_one('.article_info p.price').text)[1]
        print('가격: ', price)
        print("")
# Out:
# PAGE ==================== 1
# 상품명: 레이어드 크루 넥 반팔 티셔츠_일반 기장 [화이트]
# 브랜드: 무신사 스탠다드
# 가격:  16,900원
#
# 상품명: 베이식 긴팔 티셔츠 2팩
# 브랜드: 무신사 스탠다드
# 가격:  37,800원
#
# 상품명: [무료반품] 워셔블 하찌 니트 - 11 COLOR
# 브랜드: 수아레
# 가격:  39,900원
#
# 상품명: 레이어드 크루 넥 반팔 티셔츠_긴 기장 [화이트]
# 브랜드: 무신사 스탠다드
# 가격:  16,900원
#
# 상품명: [2PACK] 베이식 무지 레이어드 반팔 티셔츠 일반 기장...
# 브랜드: 프린트스타
# 가격:  16,900원
#
# 상품명: 레이어드 크루 넥 반팔 티셔츠_일반 기장 2팩
# 브랜드: 무신사 스탠다드
# 가격:  33,800원
#
# 상품명: 릴렉스 핏 크루 넥 반팔 티셔츠 [화이트]
# 브랜드: 무신사 스탠다드
# 가격:  15,900원
#
# 상품명: [깡스타일리스트 PICK] (시티보이) 오버핏 옥스포드 셔...
# 브랜드: 스파오
# 가격:  35,910원
#
# 상품명: 에센셜 후드 스웻 셔츠 (MELANGE GREY)
# 브랜드: 토피
# 가격:  39,000원
#
# 상품명: [패키지 상품] Longsleeve 무지 긴팔티
# 브랜드: 브렌슨
# 가격:  29,900원
#
# 상품명: 베이식 긴팔 티셔츠 [화이트]
# 브랜드: 무신사 스탠다드
# 가격:  18,900원
#
# 상품명: 980g pigment mtm-charcoal-
# 브랜드: 소버먼트
# 가격:  49,200원
#
# 상품명: 코튼 워셔블 하찌 하프집업 니트_5 COLOR
# 브랜드: 키뮤어
# 가격:  42,900원
#
# 상품명: [SS Ver.]헤비 코튼 오버 럭비 맨투맨_Midnigh...
# 브랜드: 라퍼지스토어
# 가격:  36,000원
#
# 상품명: 베이식 크루 넥 반팔 티셔츠 [화이트]
# 브랜드: 무신사 스탠다드
# 가격:  13,900원
#
# 상품명: [무료반품] 화란 세미오버 니트 블랙
# 브랜드: 엘무드
# 가격:  61,600원
#
# 상품명: LEISURE TIME LOGO SWEATSHIRT NAV...
# 브랜드: 아메스 월드와이드
# 가격:  44,800원
#
# 상품명: [무료반품] [리뉴얼] 하프 터틀넥 니트 세트
# 브랜드: 수아레
# 가격:  39,900원
#
# 상품명: (23SS) 2 TONE ARCH HOODIE GRAY
# 브랜드: 예일
# 가격:  55,300원
#
# 상품명: DON’T PANIC PIGMENT SWEATSHIRT P...
# 브랜드: 마하그리드
# 가격:  51,800원
#
# 상품명: 스웨트셔츠 [블랙]
# 브랜드: 무신사 스탠다드
# 가격:  29,900원
#
# 상품명: 에센셜 쿨 코튼 2-PACK 티셔츠 블랙
# 브랜드: 커버낫
# 가격:  44,100원
#
# 상품명: 우먼즈 베이식 크루 넥 반팔 티셔츠 [화이트]
# 브랜드: 무신사 스탠다드
# 가격:  13,900원
#
# 상품명: 워셔블 하프 집업 카라넥 하찌 니트 (PURE BLACK)...
# 브랜드: 트릴리온
# 가격:  39,800원
#
# 상품명: [SET] (맨투맨 OR 후드 선택) CGP 아치 로고 트...
# 브랜드: 코드그라피
# 가격:  72,900원
#
# 상품명: 카라 케이블 니트 집업 블랙
# 브랜드: 굿라이프웍스
# 가격:  63,000원
#
# 상품명: SIGN LOGO HOOD GRAY
# 브랜드: 와릿이즌
# 가격:  31,050원
#
# 상품명: 릴렉스 핏 크루 넥 반팔 티셔츠 [블랙]
# 브랜드: 무신사 스탠다드
# 가격:  15,900원
#
# 상품명: 로그 오버핏 기모 후드 그레이 YHHD2302
# 브랜드: 제멋
# 가격:  34,900원
#
# 상품명: [3-PACK]베이직 트래블러 피그먼트 스웨트셔츠
# 브랜드: 트래블
# 가격:  59,900원
#
# 상품명: [세트]  하프 폴라 니트 티셔츠
# 브랜드: 이에스엔
# 가격:  35,100원
#
# 상품명: SIGN LOGO HOOD BLACK
# 브랜드: 와릿이즌
# 가격:  31,050원
#
# 상품명: 고밀도순면기본반팔티셔츠_3팩 MATS0101
# 브랜드: 마인드브릿지
# 가격:  19,900원
#
# 상품명: 릴렉스 핏 옥스포드 셔츠 [화이트]
# 브랜드: 무신사 스탠다드
# 가격:  33,900원
#
# 상품명: 램스울 크루넥 오버니트(연차콜)
# 브랜드: 테이크이지
# 가격:  37,800원
#
# 상품명: 하이 벤트 레이어드 티셔츠 [WHITE]
# 브랜드: 드로우핏
# 가격:  29,250원
#
# 상품명: 릴렉스 핏 크루 넥 반팔 티셔츠 2팩
# 브랜드: 무신사 스탠다드
# 가격:  31,800원
#
# 상품명: 베이식 긴팔 티셔츠 [블랙]
# 브랜드: 무신사 스탠다드
# 가격:  18,900원
#
# 상품명: 크루넥 리브 니트 스웨터_블랙
# 브랜드: 블론드나인
# 가격:  28,800원
#
# 상품명: 베이식 크루 넥 반팔 티셔츠 2팩
# 브랜드: 무신사 스탠다드
# 가격:  27,800원
#
# 상품명: 크래킹 스냅 레글런 후드티 블랙
# 브랜드: 꼼파뇨
# 가격:  59,800원
#
# 상품명: 오버핏 아치 로고 스웨트 셔츠-그린
# 브랜드: 필루미네이트
# 가격:  39,900원
#
# 상품명: 램스울 크루넥 오버니트(블랙)
# 브랜드: 테이크이지
# 가격:  37,800원
#
# 상품명: 오버사이즈 집업 카라 터틀넥 니트 [M.GREY]
# 브랜드: 드로우핏
# 가격:  68,400원
#
# 상품명: [드로우핏X깡스타일리스트] 모크넥 니트 티셔츠 SET
# 브랜드: 드로우핏
# 가격:  43,900원
#
# 상품명: (23SS) 2 TONE ARCH TEE WHITE
# 브랜드: 예일
# 가격:  35,100원
#
# 상품명: [SET] (맨투맨 OR 후드 선택) CGP 아치 로고 트...
# 브랜드: 코드그라피
# 가격:  72,900원
#
# 상품명: [블랙]SET B-스테디 하프 폴라넥
# 브랜드: 필루미네이트
# 가격:  29,900원
#
# 상품명: RALLY COLLARED SWEATSHIRT NAVY(M...
# 브랜드: 마하그리드
# 가격:  66,600원
#
# 상품명: 컬러 배색 1992 그래픽 후드 (NAVY)
# 브랜드: 트릴리온
# 가격:  39,800원
#
# 상품명: [무료반품] 트위드 크루넥 니트웨어_레몬블랙
# 브랜드: 인템포무드
# 가격:  58,700원
#
# 상품명: 021541 레이어드 반팔 티셔츠(2pck)
# 브랜드: 지오다노
# 가격:  16,800원
#
# 상품명: LAUNDRY SHIRT (LAVENDER GRAY)
# 브랜드: 유니온블루
# 가격:  59,000원
#
# 상품명: [기모] Geppetto 자수 후드 크림
# 브랜드: 꼼파뇨
# 가격:  46,800원
#
# 상품명: [무료반품] [니티드X깡스타일리스트] 코튼 미니멀 라운드 ...
# 브랜드: 니티드
# 가격:  59,400원
#
# 상품명: PHYPS® STRAWBERRY HOODIE OATMEAL...
# 브랜드: 피지컬 에듀케이션 디파트먼트
# 가격:  57,400원
#
# 상품명: 피치스킨 벌룬오버 후드 - 블랙
# 브랜드: 엠오오
# 가격:  49,600원
#
# 상품명: 쿨 코튼 2-PACK 티셔츠 화이트
# 브랜드: 커버낫
# 가격:  34,400원
#
# 상품명: (솔리드 OR 멀티트위드 선택)_12컬러 코튼 워셔블 하찌...
# 브랜드: 키뮤어
# 가격:  39,900원
#
# 상품명: (23SS) (YALE HEAVYWEIGHT) MIXED ...
# 브랜드: 예일
# 가격:  62,300원
#
# 상품명: 워셔블 하프 집업 카라넥 하찌 니트 (CURRENT NAV...
# 브랜드: 트릴리온
# 가격:  39,800원
#
# 상품명: 에센셜 후드 스웻 셔츠 (BLACK)
# 브랜드: 토피
# 가격:  39,000원
#
# 상품명: SMALL SIGN LOGO SWEATSHIRT BLACK...
# 브랜드: 와릿이즌
# 가격:  23,600원
#
# 상품명: 950g solid hoody-deep black-
# 브랜드: 소버먼트
# 가격:  62,400원
#
# 상품명: 솔리드 케이블 니트 풀오버 투웨이 집업 가디건 카라 자켓
# 브랜드: 플레이스 스튜디오
# 가격:  39,800원
#
# 상품명: 오버핏 아치 로고 스웨트 셔츠-네이비
# 브랜드: 필루미네이트
# 가격:  39,900원
#
# 상품명: 베이식 드레스 셔츠 [화이트]
# 브랜드: 무신사 스탠다드
# 가격:  33,900원
#
# 상품명: [패키지] 더블코튼 무지반팔  패키지 KHST1011
# 브랜드: 페플
# 가격:  29,900원
#
# 상품명: [패키지] 에센셜 레이어드 롱 슬리브 티셔츠
# 브랜드: 트릴리온
# 가격:  39,800원
#
# 상품명: 슬레이크 후드 네이비 HHHD3397
# 브랜드: 티떠블유엔
# 가격:  41,900원
#
# 상품명: 슬레이크 후드 올리브 HHHD3397
# 브랜드: 티떠블유엔
# 가격:  41,900원
#
# 상품명: 폰테 크루 넥 긴팔 티셔츠 [오프 화이트]
# 브랜드: 무신사 스탠다드
# 가격:  21,090원
#
# 상품명: UNISEX LAUREL OVERSIZED HOODIE -...
# 브랜드: 어반드레스
# 가격:  35,880원
#
# 상품명: [호시 착용] [SET] (긴바지 OR 반바지 선택) 24...
# 브랜드: 코드그라피
# 가격:  78,900원
#
# 상품명: (23SS) 2 TONE ARCH HOODIE BLACK
# 브랜드: 예일
# 가격:  55,300원
#
# 상품명: 솔리드 옥스포드 오버셔츠(화이트)
# 브랜드: 테이크이지
# 가격:  40,200원
#
# 상품명: [무료반품] 투톤 사선 라운드 니트 - 퍼플
# 브랜드: 르마드
# 가격:  72,000원
#
# 상품명: (23SS) [ONEMILE WEAR] SMALL ARCH...
# 브랜드: 예일
# 가격:  49,000원
#
# 상품명: [UNISEX] 45수 특양면 옆트임 오버핏 반팔티 (화이...
# 브랜드: 티아즈
# 가격:  14,700원
#
# 상품명: 미시간 울버린 피그먼트 후드티 블랙 차콜
# 브랜드: 트래블
# 가격:  54,900원
#
# 상품명: 레이어드 크루 넥 긴팔 티셔츠_일반 기장 [화이트]
# 브랜드: 무신사 스탠다드
# 가격:  19,900원
#
# 상품명: [무료반품] 브룩 니트 ( 5 COLOR )
# 브랜드: 엘무드
# 가격:  71,900원
#
# 상품명: 헤비웨이트 오버사이즈 스웨트셔츠 [블랙]
# 브랜드: 무신사 스탠다드
# 가격:  31,790원
#
# 상품명: 오버핏 아치 로고 스웨트 셔츠-와인
# 브랜드: 필루미네이트
# 가격:  39,900원
#
# 상품명: [무료반품] 화란 세미오버 니트 크림
# 브랜드: 엘무드
# 가격:  61,600원
#
# 상품명: 램스울 크루넥 오버니트(헤더블루)
# 브랜드: 테이크이지
# 가격:  37,800원
#
# 상품명: LAUNDRY SHIRT (LEMON)
# 브랜드: 유니온블루
# 가격:  59,000원
#
# 상품명: 베이식 크루 넥 반팔 티셔츠 [블랙]
# 브랜드: 무신사 스탠다드
# 가격:  13,900원
#
# 상품명: [2PACK] 7.5oz 헤비웨이트 무지 오버핏 레이어드 ...
# 브랜드: 샤카웨어
# 가격:  32,900원
#
# 상품명: 오버사이즈 집업 카라 터틀넥 니트 [BLACK]
# 브랜드: 드로우핏
# 가격:  68,400원
#
# PAGE ==================== 2
# 상품명: TAG HOODIE - BLACK
# 브랜드: 브라운브레스
# 가격:  63,200원
#
# 상품명: [드로우핏X깡스타일리스트] 터틀넥 니트 티셔츠 SET
# 브랜드: 드로우핏
# 가격:  43,900원
#
# 상품명: TAG HOODIE - ASH
# 브랜드: 브라운브레스
# 가격:  63,200원
#
# 상품명: [일반/기모] LT431_러닝클럽 럭비 맨투맨_네이비
# 브랜드: 어반디타입
# 가격:  36,000원
#
# 상품명: PHYPS® MONDAY ROUTINE STITCH HOO...
# 브랜드: 피지컬 에듀케이션 디파트먼트
# 가격:  55,300원
#
# 상품명: [세트상품] 더블 코튼 롱 티셔츠
# 브랜드: 어커버
# 가격:  25,900원
#
# 상품명: Traveler Oversized Sweater(TEAL ...
# 브랜드: 메인부스
# 가격:  66,700원
#
# 상품명: LAUNDRY SHIRT (WHITE)
# 브랜드: 유니온블루
# 가격:  59,000원
#
# 상품명: [패키지] NYC LOCATION T-SHIRT (16CO...
# 브랜드: 그루브라임
# 가격:  35,000원
#
# 상품명: 솔리드 옥스포드 오버셔츠(스카이블루)
# 브랜드: 테이크이지
# 가격:  40,200원
#
# 상품명: 오버핏 그래피티 로고 후디-멜란지그레이
# 브랜드: 필루미네이트
# 가격:  47,900원
#
# 상품명: 옵티멀 베이직 셔츠-화이트
# 브랜드: 필루미네이트
# 가격:  39,900원
#
# 상품명: 레이어드 크루 넥 반팔 티셔츠_긴 기장 2팩
# 브랜드: 무신사 스탠다드
# 가격:  33,800원
#
# 상품명: [무료반품] 1960 sweatshirts navy
# 브랜드: 유니폼브릿지
# 가격:  65,000원
#
# 상품명: LAUNDRY SHIRT (SKY BLUE)
# 브랜드: 유니온블루
# 가격:  59,000원
#
# 상품명: 램스울 크루넥 오버니트(아이보리)
# 브랜드: 테이크이지
# 가격:  37,800원
#
# 상품명: [패키지] 올카 오버핏 스웨트셔츠 9종 2PACK KJMT...
# 브랜드: 제멋
# 가격:  47,900원
#
# 상품명: 빈티지 반 집업_다크그린
# 브랜드: 1993스튜디오
# 가격:  57,600원
#
# 상품명: [호시 착용] [SET] (긴바지 OR 반바지 선택) 90...
# 브랜드: 코드그라피
# 가격:  75,900원
#
# 상품명: 빅 트위치 로고 티셔츠 화이트
# 브랜드: 리
# 가격:  35,000원
#
# 상품명: 베이식 옥스포드 셔츠 [화이트]
# 브랜드: 무신사 스탠다드
# 가격:  33,900원
#
# 상품명: [23SS Ver.][Package]시티보이 빅오버 옥스포...
# 브랜드: 라퍼지스토어
# 가격:  59,800원
#
# 상품명: DOODLE LOGO HOODIE - BLACK
# 브랜드: 노매뉴얼
# 가격:  87,000원
#
# 상품명: EarthHeart 후드티
# 브랜드: 벤힛
# 가격:  30,900원
#
# 상품명: 쿨코튼 2-PACK 베츠 기본 반팔 티셔츠 블랙/화이트
# 브랜드: 이벳필드
# 가격:  34,300원
#
# 상품명: 90S 트랙 스웨트셔츠_블랙
# 브랜드: 1993스튜디오
# 가격:  85,000원
#
# 상품명: 하프 집업 리브 니트 탑_그레이
# 브랜드: 블론드나인
# 가격:  38,800원
#
# 상품명: SWEATSHIRT FLOWERMARDI_OATMEAL B...
# 브랜드: 마르디 메크르디
# 가격:  71,250원
#
# 상품명: [3PACK] 32수 라이트 코튼 반팔 티셔츠
# 브랜드: 프린트스타
# 가격:  18,900원
#
# 상품명: [패키지] Errday 루즈핏 맨투맨 2`nd
# 브랜드: 브렌슨
# 가격:  45,900원
#
# 상품명: 빅 트위치 루즈핏 후드 네이비
# 브랜드: 리
# 가격:  79,000원
#
# 상품명: [패키지] 베이직 크루넥 반팔티 (오버핏/트임 선택)
# 브랜드: 브렌슨
# 가격:  27,900원
#
# 상품명: 워셔블 하프 집업 카라넥 하찌 니트 (NEUTRAL GRA...
# 브랜드: 트릴리온
# 가격:  39,800원
#
# 상품명: 레이어드 슬리브리스 탑_일반 기장 [화이트]
# 브랜드: 무신사 스탠다드
# 가격:  13,390원
#
# 상품명: Velour Soccer Jersey Black
# 브랜드: 스컬프터
# 가격:  101,150원
#
# 상품명: [드로우핏X깡스타일리스트] 모크넥 니트 티셔츠
# 브랜드: 드로우핏
# 가격:  23,900원
#
# 상품명: 퍼펙트 터틀넥 니트 티셔츠 블랙
# 브랜드: 이에스엔
# 가격:  23,000원
#
# 상품명: 미시간 울버린 피그먼트 반팔티 블랙 차콜
# 브랜드: 트래블
# 가격:  29,900원
#
# 상품명: RESEARCH HOODIE [KHAKI]
# 브랜드: 비바스튜디오
# 가격:  69,800원
#
# 상품명: COLLEGE LOGO HOODIE BLACK(MG2BSM...
# 브랜드: 마하그리드
# 가격:  55,200원
#
# 상품명: 크루넥 리브 니트 스웨터_브라운
# 브랜드: 블론드나인
# 가격:  28,800원
#
# 상품명: SWEATSHIRT FLOWERMARDI BLOSSOM_N...
# 브랜드: 마르디 메크르디
# 가격:  84,550원
#
# 상품명: 피치스킨 러스티 로고 스웨트셔츠 [블랙]
# 브랜드: 슬로우애시드
# 가격:  62,100원
#
# 상품명: 오버핏 그래피티 로고 후디-블랙
# 브랜드: 필루미네이트
# 가격:  47,900원
#
# 상품명: 릴렉스 핏 크루 넥 반팔 티셔츠 2 [화이트]
# 브랜드: 무신사 스탠다드
# 가격:  14,290원
#
# 상품명: 우먼즈 릴렉스드 크루 넥 긴팔 티셔츠 [화이트]
# 브랜드: 무신사 스탠다드
# 가격:  18,900원
#
# 상품명: [쿨탠다드] 릴렉스 핏 크루 넥 반팔 티셔츠 2팩
# 브랜드: 무신사 스탠다드
# 가격:  39,800원
#
# 상품명: 오버핏 아치 로고 스웨트 셔츠-크림
# 브랜드: 필루미네이트
# 가격:  39,900원
#
# 상품명: 미니멀 크루 넥 니트 [블랙]
# 브랜드: 무신사 스탠다드
# 가격:  59,390원
#
# 상품명: 클럽 레플리카 스웻셔츠 [오프 화이트]
# 브랜드: 슈퍼서브
# 가격:  39,000원
#
# 상품명: 폰테 크루 넥 긴팔 티셔츠 [블랙]
# 브랜드: 무신사 스탠다드
# 가격:  22,390원
#
# 상품명: 헤비웨이트 오버사이즈 후디드 스웨트셔츠 [블랙]
# 브랜드: 무신사 스탠다드
# 가격:  49,900원
#
# 상품명: 빈티지 반 집업_오트베이지
# 브랜드: 1993스튜디오
# 가격:  57,600원
#
# 상품명: (23SS) 2 TONE ARCH HOODIE NAVY
# 브랜드: 예일
# 가격:  55,300원
#
# 상품명: 에센셜 후드 스웻 셔츠 (CHARCOAL)
# 브랜드: 토피
# 가격:  39,000원
#
# 상품명: 하이 벤트 레이어드 티셔츠 [BLACK]
# 브랜드: 드로우핏
# 가격:  29,250원
#
# 상품명: 오버핏 아치 로고 스웨트 셔츠-블랙
# 브랜드: 필루미네이트
# 가격:  39,900원
#
# 상품명: [무료반품] 트위드 크루넥 니트웨어_아이스블루
# 브랜드: 인템포무드
# 가격:  58,700원
#
# 상품명: TC5-SH08 프렌치 스트라이프 셔츠-네이비
# 브랜드: 토마스모어
# 가격:  56,715원
#
# 상품명: 아치 팬시 로고 후드티_화이트메란지
# 브랜드: 어나더 아카이브
# 가격:  35,800원
#
# 상품명: 캠프 바시티 피그먼트 스웨트셔츠 블루 섀도우
# 브랜드: 트래블
# 가격:  49,900원
#
# 상품명: 빈티지 반 집업_라이트그레이
# 브랜드: 1993스튜디오
# 가격:  50,400원
#
# 상품명: 크루 넥 긴팔 티셔츠 [화이트]
# 브랜드: 무신사 스탠다드
# 가격:  19,900원
#
# 상품명: 로그 오버핏 기모 후드 블랙 YHHD2302
# 브랜드: 제멋
# 가격:  34,900원
#
# 상품명: [SS Ver.]헤비 코튼 오버 럭비 맨투맨_Black
# 브랜드: 라퍼지스토어
# 가격:  36,000원
#
# 상품명: ROUND LOGO CREWNECK SWEATSHIRT B...
# 브랜드: 프렌다
# 가격:  47,200원
#
# 상품명: [레드벨벳 웬디 PICK] [패키지] NYC LOCATIO...
# 브랜드: 그루브라임
# 가격:  69,000원
#
# 상품명: (23SS) [ONEMILE WEAR] SMALL ARCH...
# 브랜드: 예일
# 가격:  49,000원
#
# 상품명: [무료반품] 울 오버핏 라운드 니트 - 오렌지
# 브랜드: 르마드
# 가격:  68,400원
#
# 상품명: 코튼 워셔블 후드니트
# 브랜드: 키뮤어
# 가격:  54,900원
#
# 상품명: [무료반품] [니티드X깡스타일리스트] 코튼 미니멀 라운드 ...
# 브랜드: 니티드
# 가격:  59,400원
#
# 상품명: [논기모]나마스테 스켈레톤 후디_핑크(NG2DSUM403A...
# 브랜드: 나이스고스트클럽
# 가격:  63,200원
#
# 상품명: 크루넥 리브 니트 스웨터_스카이 블루
# 브랜드: 블론드나인
# 가격:  28,800원
#
# 상품명: 크루넥 리브 니트 스웨터_네이비
# 브랜드: 블론드나인
# 가격:  28,800원
#
# 상품명: (23SS) EMBROIDERY UNIVERSITY DAN...
# 브랜드: 예일
# 가격:  55,300원
#
# 상품명: [무료반품] 해비 코튼 썸홀 후디 : 15color
# 브랜드: 인템포무드
# 가격:  73,900원
#
# 상품명: 케이블 카라 니트[그린]
# 브랜드: 시그니처
# 가격:  53,000원
#
# 상품명: 레이어드 크루 넥 반팔 티셔츠_일반 기장 [블랙]
# 브랜드: 무신사 스탠다드
# 가격:  16,900원
#
# 상품명: 베츠 어센틱 맨투맨 그레이
# 브랜드: 이벳필드
# 가격:  27,600원
#
# 상품명: 오버핏 울 체크 셔츠 그레이
# 브랜드: 어반드레스
# 가격:  39,840원
#
# 상품명: 오버핏 그래피티 로고 후디-오트밀
# 브랜드: 필루미네이트
# 가격:  47,900원
#
# 상품명: 크루넥 리브 니트 스웨터_아이보리
# 브랜드: 블론드나인
# 가격:  28,800원
#
# 상품명: (23SS) 2 TONE ARCH TEE ROYAL BLU...
# 브랜드: 예일
# 가격:  35,100원
#
# 상품명: COLLEGE LOGO HOODIE GREY(MG2BSMM...
# 브랜드: 마하그리드
# 가격:  55,200원
#
# 상품명: [3PACK] 베이식 무지 레이어드 반팔 티셔츠 일반 기장...
# 브랜드: 프린트스타
# 가격:  24,500원
#
# 상품명: [23SS Ver.]시티보이 빅오버 옥스포드 셔츠_Roya...
# 브랜드: 라퍼지스토어
# 가격:  36,800원
#
# 상품명: [SET] (맨투맨 OR 후드 선택) CGP 아치 로고 트...
# 브랜드: 코드그라피
# 가격:  72,900원
#
# 상품명: 후디드 스웨트셔츠 [멜란지 그레이]
# 브랜드: 무신사 스탠다드
# 가격:  33,990원
#
# 상품명: [패키지] 로그 오버핏 기모 후드 2Pack YHHD230...
# 브랜드: 제멋
# 가격:  62,500원
#
# 상품명: [드로우핏X깡스타일리스트] 터틀넥 니트 티셔츠
# 브랜드: 드로우핏
# 가격:  23,900원

# %%
for i in range(1,3):
    print('PAGE ==============', i)
    url = f'https://www.musinsa.com/categories/item/001?d_cat_cd=001&brand=&list_kind=small&sort=pop_category&sub_sort=&page={i}&display_cnt=90&group_sale=&exclusive_yn=&sale_goods=&timesale_yn=&ex_soldout=&kids=&color=&price1=&price2=&shoeSizeOption=&tags=&campaign_id=&includeKeywords=&measure='
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    
    for item in soup.select("ul#searchList>li"):
        print('상품명:', item.select_one(".article_info p.list_info a").attrs['title'])
        print('브랜드:', item.select_one(".article_info p.item_title").text.strip())
        price =""

        # 가격에서 쉼표와 원을 제거 해보기 실패~~!!
        if len(re.findall('[0-9,]*원', item.select_one('.article_info p.price').text)) == 1:
            price = int(re.sub(r'[^\d ]*원', '', item.select_one('.article_info p.price').text).split()[0].replace(",", ""))
             
        else:
            price = int(re.sub(r'[^\d ]*원', '', item.select_one('.article_info p.price').text).split()[1].replace(",", ""))
        print('가격: ', price)
        print('')
# Out:
# PAGE ============== 1
# 상품명: 레이어드 크루 넥 반팔 티셔츠_일반 기장 [화이트]
# 브랜드: 무신사 스탠다드
# 가격:  16900
#
# 상품명: 베이식 긴팔 티셔츠 2팩
# 브랜드: 무신사 스탠다드
# 가격:  37800
#
# 상품명: [무료반품] 워셔블 하찌 니트 - 11 COLOR
# 브랜드: 수아레
# 가격:  39900
#
# 상품명: 레이어드 크루 넥 반팔 티셔츠_긴 기장 [화이트]
# 브랜드: 무신사 스탠다드
# 가격:  16900
#
# 상품명: [2PACK] 베이식 무지 레이어드 반팔 티셔츠 일반 기장...
# 브랜드: 프린트스타
# 가격:  16900
#
# 상품명: 레이어드 크루 넥 반팔 티셔츠_일반 기장 2팩
# 브랜드: 무신사 스탠다드
# 가격:  33800
#
# 상품명: 릴렉스 핏 크루 넥 반팔 티셔츠 [화이트]
# 브랜드: 무신사 스탠다드
# 가격:  15900
#
# 상품명: [깡스타일리스트 PICK] (시티보이) 오버핏 옥스포드 셔...
# 브랜드: 스파오
# 가격:  35910
#
# 상품명: 에센셜 후드 스웻 셔츠 (MELANGE GREY)
# 브랜드: 토피
# 가격:  39000
#
# 상품명: [패키지 상품] Longsleeve 무지 긴팔티
# 브랜드: 브렌슨
# 가격:  29900
#
# 상품명: 베이식 긴팔 티셔츠 [화이트]
# 브랜드: 무신사 스탠다드
# 가격:  18900
#
# 상품명: 980g pigment mtm-charcoal-
# 브랜드: 소버먼트
# 가격:  49200
#
# 상품명: 코튼 워셔블 하찌 하프집업 니트_5 COLOR
# 브랜드: 키뮤어
# 가격:  42900
#
# 상품명: [SS Ver.]헤비 코튼 오버 럭비 맨투맨_Midnigh...
# 브랜드: 라퍼지스토어
# 가격:  36000
#
# 상품명: 베이식 크루 넥 반팔 티셔츠 [화이트]
# 브랜드: 무신사 스탠다드
# 가격:  13900
#
# 상품명: [무료반품] 화란 세미오버 니트 블랙
# 브랜드: 엘무드
# 가격:  61600
#
# 상품명: LEISURE TIME LOGO SWEATSHIRT NAV...
# 브랜드: 아메스 월드와이드
# 가격:  44800
#
# 상품명: [무료반품] [리뉴얼] 하프 터틀넥 니트 세트
# 브랜드: 수아레
# 가격:  39900
#
# 상품명: (23SS) 2 TONE ARCH HOODIE GRAY
# 브랜드: 예일
# 가격:  55300
#
# 상품명: DON’T PANIC PIGMENT SWEATSHIRT P...
# 브랜드: 마하그리드
# 가격:  51800
#
# 상품명: 스웨트셔츠 [블랙]
# 브랜드: 무신사 스탠다드
# 가격:  29900
#
# 상품명: 에센셜 쿨 코튼 2-PACK 티셔츠 블랙
# 브랜드: 커버낫
# 가격:  44100
#
# 상품명: 우먼즈 베이식 크루 넥 반팔 티셔츠 [화이트]
# 브랜드: 무신사 스탠다드
# 가격:  13900
#
# 상품명: 워셔블 하프 집업 카라넥 하찌 니트 (PURE BLACK)...
# 브랜드: 트릴리온
# 가격:  39800
#
# 상품명: [SET] (맨투맨 OR 후드 선택) CGP 아치 로고 트...
# 브랜드: 코드그라피
# 가격:  72900
#
# 상품명: 카라 케이블 니트 집업 블랙
# 브랜드: 굿라이프웍스
# 가격:  63000
#
# 상품명: SIGN LOGO HOOD GRAY
# 브랜드: 와릿이즌
# 가격:  31050
#
# 상품명: 릴렉스 핏 크루 넥 반팔 티셔츠 [블랙]
# 브랜드: 무신사 스탠다드
# 가격:  15900
#
# 상품명: 로그 오버핏 기모 후드 그레이 YHHD2302
# 브랜드: 제멋
# 가격:  34900
#
# 상품명: [3-PACK]베이직 트래블러 피그먼트 스웨트셔츠
# 브랜드: 트래블
# 가격:  59900
#
# 상품명: [세트]  하프 폴라 니트 티셔츠
# 브랜드: 이에스엔
# 가격:  35100
#
# 상품명: SIGN LOGO HOOD BLACK
# 브랜드: 와릿이즌
# 가격:  31050
#
# 상품명: 고밀도순면기본반팔티셔츠_3팩 MATS0101
# 브랜드: 마인드브릿지
# 가격:  19900
#
# 상품명: 릴렉스 핏 옥스포드 셔츠 [화이트]
# 브랜드: 무신사 스탠다드
# 가격:  33900
#
# 상품명: 램스울 크루넥 오버니트(연차콜)
# 브랜드: 테이크이지
# 가격:  37800
#
# 상품명: 하이 벤트 레이어드 티셔츠 [WHITE]
# 브랜드: 드로우핏
# 가격:  29250
#
# 상품명: 릴렉스 핏 크루 넥 반팔 티셔츠 2팩
# 브랜드: 무신사 스탠다드
# 가격:  31800
#
# 상품명: 베이식 긴팔 티셔츠 [블랙]
# 브랜드: 무신사 스탠다드
# 가격:  18900
#
# 상품명: 크루넥 리브 니트 스웨터_블랙
# 브랜드: 블론드나인
# 가격:  28800
#
# 상품명: 베이식 크루 넥 반팔 티셔츠 2팩
# 브랜드: 무신사 스탠다드
# 가격:  27800
#
# 상품명: 크래킹 스냅 레글런 후드티 블랙
# 브랜드: 꼼파뇨
# 가격:  59800
#
# 상품명: 오버핏 아치 로고 스웨트 셔츠-그린
# 브랜드: 필루미네이트
# 가격:  39900
#
# 상품명: 램스울 크루넥 오버니트(블랙)
# 브랜드: 테이크이지
# 가격:  37800
#
# 상품명: 오버사이즈 집업 카라 터틀넥 니트 [M.GREY]
# 브랜드: 드로우핏
# 가격:  68400
#
# 상품명: [드로우핏X깡스타일리스트] 모크넥 니트 티셔츠 SET
# 브랜드: 드로우핏
# 가격:  43900
#
# 상품명: (23SS) 2 TONE ARCH TEE WHITE
# 브랜드: 예일
# 가격:  35100
#
# 상품명: [SET] (맨투맨 OR 후드 선택) CGP 아치 로고 트...
# 브랜드: 코드그라피
# 가격:  72900
#
# 상품명: [블랙]SET B-스테디 하프 폴라넥
# 브랜드: 필루미네이트
# 가격:  29900
#
# 상품명: RALLY COLLARED SWEATSHIRT NAVY(M...
# 브랜드: 마하그리드
# 가격:  66600
#
# 상품명: 컬러 배색 1992 그래픽 후드 (NAVY)
# 브랜드: 트릴리온
# 가격:  39800
#
# 상품명: [무료반품] 트위드 크루넥 니트웨어_레몬블랙
# 브랜드: 인템포무드
# 가격:  58700
#
# 상품명: 021541 레이어드 반팔 티셔츠(2pck)
# 브랜드: 지오다노
# 가격:  16800
#
# 상품명: LAUNDRY SHIRT (LAVENDER GRAY)
# 브랜드: 유니온블루
# 가격:  59000
#
# 상품명: [기모] Geppetto 자수 후드 크림
# 브랜드: 꼼파뇨
# 가격:  46800
#
# 상품명: [무료반품] [니티드X깡스타일리스트] 코튼 미니멀 라운드 ...
# 브랜드: 니티드
# 가격:  59400
#
# 상품명: PHYPS® STRAWBERRY HOODIE OATMEAL...
# 브랜드: 피지컬 에듀케이션 디파트먼트
# 가격:  57400
#
# 상품명: 피치스킨 벌룬오버 후드 - 블랙
# 브랜드: 엠오오
# 가격:  49600
#
# 상품명: 쿨 코튼 2-PACK 티셔츠 화이트
# 브랜드: 커버낫
# 가격:  34400
#
# 상품명: (솔리드 OR 멀티트위드 선택)_12컬러 코튼 워셔블 하찌...
# 브랜드: 키뮤어
# 가격:  39900
#
# 상품명: (23SS) (YALE HEAVYWEIGHT) MIXED ...
# 브랜드: 예일
# 가격:  62300
#
# 상품명: 워셔블 하프 집업 카라넥 하찌 니트 (CURRENT NAV...
# 브랜드: 트릴리온
# 가격:  39800
#
# 상품명: 에센셜 후드 스웻 셔츠 (BLACK)
# 브랜드: 토피
# 가격:  39000
#
# 상품명: SMALL SIGN LOGO SWEATSHIRT BLACK...
# 브랜드: 와릿이즌
# 가격:  23600
#
# 상품명: 950g solid hoody-deep black-
# 브랜드: 소버먼트
# 가격:  62400
#
# 상품명: 솔리드 케이블 니트 풀오버 투웨이 집업 가디건 카라 자켓
# 브랜드: 플레이스 스튜디오
# 가격:  39800
#
# 상품명: 오버핏 아치 로고 스웨트 셔츠-네이비
# 브랜드: 필루미네이트
# 가격:  39900
#
# 상품명: 베이식 드레스 셔츠 [화이트]
# 브랜드: 무신사 스탠다드
# 가격:  33900
#
# 상품명: [패키지] 더블코튼 무지반팔  패키지 KHST1011
# 브랜드: 페플
# 가격:  29900
#
# 상품명: [패키지] 에센셜 레이어드 롱 슬리브 티셔츠
# 브랜드: 트릴리온
# 가격:  39800
#
# 상품명: 슬레이크 후드 네이비 HHHD3397
# 브랜드: 티떠블유엔
# 가격:  41900
#
# 상품명: 슬레이크 후드 올리브 HHHD3397
# 브랜드: 티떠블유엔
# 가격:  41900
#
# 상품명: 폰테 크루 넥 긴팔 티셔츠 [오프 화이트]
# 브랜드: 무신사 스탠다드
# 가격:  21090
#
# 상품명: UNISEX LAUREL OVERSIZED HOODIE -...
# 브랜드: 어반드레스
# 가격:  35880
#
# 상품명: [호시 착용] [SET] (긴바지 OR 반바지 선택) 24...
# 브랜드: 코드그라피
# 가격:  78900
#
# 상품명: (23SS) 2 TONE ARCH HOODIE BLACK
# 브랜드: 예일
# 가격:  55300
#
# 상품명: 솔리드 옥스포드 오버셔츠(화이트)
# 브랜드: 테이크이지
# 가격:  40200
#
# 상품명: [무료반품] 투톤 사선 라운드 니트 - 퍼플
# 브랜드: 르마드
# 가격:  72000
#
# 상품명: (23SS) [ONEMILE WEAR] SMALL ARCH...
# 브랜드: 예일
# 가격:  49000
#
# 상품명: [UNISEX] 45수 특양면 옆트임 오버핏 반팔티 (화이...
# 브랜드: 티아즈
# 가격:  14700
#
# 상품명: 미시간 울버린 피그먼트 후드티 블랙 차콜
# 브랜드: 트래블
# 가격:  54900
#
# 상품명: 레이어드 크루 넥 긴팔 티셔츠_일반 기장 [화이트]
# 브랜드: 무신사 스탠다드
# 가격:  19900
#
# 상품명: [무료반품] 브룩 니트 ( 5 COLOR )
# 브랜드: 엘무드
# 가격:  71900
#
# 상품명: 헤비웨이트 오버사이즈 스웨트셔츠 [블랙]
# 브랜드: 무신사 스탠다드
# 가격:  31790
#
# 상품명: 오버핏 아치 로고 스웨트 셔츠-와인
# 브랜드: 필루미네이트
# 가격:  39900
#
# 상품명: [무료반품] 화란 세미오버 니트 크림
# 브랜드: 엘무드
# 가격:  61600
#
# 상품명: 램스울 크루넥 오버니트(헤더블루)
# 브랜드: 테이크이지
# 가격:  37800
#
# 상품명: LAUNDRY SHIRT (LEMON)
# 브랜드: 유니온블루
# 가격:  59000
#
# 상품명: 베이식 크루 넥 반팔 티셔츠 [블랙]
# 브랜드: 무신사 스탠다드
# 가격:  13900
#
# 상품명: [2PACK] 7.5oz 헤비웨이트 무지 오버핏 레이어드 ...
# 브랜드: 샤카웨어
# 가격:  32900
#
# 상품명: 오버사이즈 집업 카라 터틀넥 니트 [BLACK]
# 브랜드: 드로우핏
# 가격:  68400
#
# PAGE ============== 2
# 상품명: TAG HOODIE - BLACK
# 브랜드: 브라운브레스
# 가격:  63200
#
# 상품명: [드로우핏X깡스타일리스트] 터틀넥 니트 티셔츠 SET
# 브랜드: 드로우핏
# 가격:  43900
#
# 상품명: TAG HOODIE - ASH
# 브랜드: 브라운브레스
# 가격:  63200
#
# 상품명: [일반/기모] LT431_러닝클럽 럭비 맨투맨_네이비
# 브랜드: 어반디타입
# 가격:  36000
#
# 상품명: PHYPS® MONDAY ROUTINE STITCH HOO...
# 브랜드: 피지컬 에듀케이션 디파트먼트
# 가격:  55300
#
# 상품명: [세트상품] 더블 코튼 롱 티셔츠
# 브랜드: 어커버
# 가격:  25900
#
# 상품명: Traveler Oversized Sweater(TEAL ...
# 브랜드: 메인부스
# 가격:  66700
#
# 상품명: LAUNDRY SHIRT (WHITE)
# 브랜드: 유니온블루
# 가격:  59000
#
# 상품명: [패키지] NYC LOCATION T-SHIRT (16CO...
# 브랜드: 그루브라임
# 가격:  35000
#
# 상품명: 솔리드 옥스포드 오버셔츠(스카이블루)
# 브랜드: 테이크이지
# 가격:  40200
#
# 상품명: 오버핏 그래피티 로고 후디-멜란지그레이
# 브랜드: 필루미네이트
# 가격:  47900
#
# 상품명: 옵티멀 베이직 셔츠-화이트
# 브랜드: 필루미네이트
# 가격:  39900
#
# 상품명: 레이어드 크루 넥 반팔 티셔츠_긴 기장 2팩
# 브랜드: 무신사 스탠다드
# 가격:  33800
#
# 상품명: [무료반품] 1960 sweatshirts navy
# 브랜드: 유니폼브릿지
# 가격:  65000
#
# 상품명: LAUNDRY SHIRT (SKY BLUE)
# 브랜드: 유니온블루
# 가격:  59000
#
# 상품명: 램스울 크루넥 오버니트(아이보리)
# 브랜드: 테이크이지
# 가격:  37800
#
# 상품명: [패키지] 올카 오버핏 스웨트셔츠 9종 2PACK KJMT...
# 브랜드: 제멋
# 가격:  47900
#
# 상품명: 빈티지 반 집업_다크그린
# 브랜드: 1993스튜디오
# 가격:  57600
#
# 상품명: [호시 착용] [SET] (긴바지 OR 반바지 선택) 90...
# 브랜드: 코드그라피
# 가격:  75900
#
# 상품명: 빅 트위치 로고 티셔츠 화이트
# 브랜드: 리
# 가격:  35000
#
# 상품명: 베이식 옥스포드 셔츠 [화이트]
# 브랜드: 무신사 스탠다드
# 가격:  33900
#
# 상품명: [23SS Ver.][Package]시티보이 빅오버 옥스포...
# 브랜드: 라퍼지스토어
# 가격:  59800
#
# 상품명: DOODLE LOGO HOODIE - BLACK
# 브랜드: 노매뉴얼
# 가격:  87000
#
# 상품명: EarthHeart 후드티
# 브랜드: 벤힛
# 가격:  30900
#
# 상품명: 쿨코튼 2-PACK 베츠 기본 반팔 티셔츠 블랙/화이트
# 브랜드: 이벳필드
# 가격:  34300
#
# 상품명: 90S 트랙 스웨트셔츠_블랙
# 브랜드: 1993스튜디오
# 가격:  85000
#
# 상품명: 하프 집업 리브 니트 탑_그레이
# 브랜드: 블론드나인
# 가격:  38800
#
# 상품명: SWEATSHIRT FLOWERMARDI_OATMEAL B...
# 브랜드: 마르디 메크르디
# 가격:  71250
#
# 상품명: [3PACK] 32수 라이트 코튼 반팔 티셔츠
# 브랜드: 프린트스타
# 가격:  18900
#
# 상품명: [패키지] Errday 루즈핏 맨투맨 2`nd
# 브랜드: 브렌슨
# 가격:  45900
#
# 상품명: 빅 트위치 루즈핏 후드 네이비
# 브랜드: 리
# 가격:  79000
#
# 상품명: [패키지] 베이직 크루넥 반팔티 (오버핏/트임 선택)
# 브랜드: 브렌슨
# 가격:  27900
#
# 상품명: 워셔블 하프 집업 카라넥 하찌 니트 (NEUTRAL GRA...
# 브랜드: 트릴리온
# 가격:  39800
#
# 상품명: 레이어드 슬리브리스 탑_일반 기장 [화이트]
# 브랜드: 무신사 스탠다드
# 가격:  13390
#
# 상품명: Velour Soccer Jersey Black
# 브랜드: 스컬프터
# 가격:  101150
#
# 상품명: [드로우핏X깡스타일리스트] 모크넥 니트 티셔츠
# 브랜드: 드로우핏
# 가격:  23900
#
# 상품명: 퍼펙트 터틀넥 니트 티셔츠 블랙
# 브랜드: 이에스엔
# 가격:  23000
#
# 상품명: 미시간 울버린 피그먼트 반팔티 블랙 차콜
# 브랜드: 트래블
# 가격:  29900
#
# 상품명: RESEARCH HOODIE [KHAKI]
# 브랜드: 비바스튜디오
# 가격:  69800
#
# 상품명: COLLEGE LOGO HOODIE BLACK(MG2BSM...
# 브랜드: 마하그리드
# 가격:  55200
#
# 상품명: 크루넥 리브 니트 스웨터_브라운
# 브랜드: 블론드나인
# 가격:  28800
#
# 상품명: SWEATSHIRT FLOWERMARDI BLOSSOM_N...
# 브랜드: 마르디 메크르디
# 가격:  84550
#
# 상품명: 피치스킨 러스티 로고 스웨트셔츠 [블랙]
# 브랜드: 슬로우애시드
# 가격:  62100
#
# 상품명: 오버핏 그래피티 로고 후디-블랙
# 브랜드: 필루미네이트
# 가격:  47900
#
# 상품명: 릴렉스 핏 크루 넥 반팔 티셔츠 2 [화이트]
# 브랜드: 무신사 스탠다드
# 가격:  14290
#
# 상품명: 우먼즈 릴렉스드 크루 넥 긴팔 티셔츠 [화이트]
# 브랜드: 무신사 스탠다드
# 가격:  18900
#
# 상품명: [쿨탠다드] 릴렉스 핏 크루 넥 반팔 티셔츠 2팩
# 브랜드: 무신사 스탠다드
# 가격:  39800
#
# 상품명: 오버핏 아치 로고 스웨트 셔츠-크림
# 브랜드: 필루미네이트
# 가격:  39900
#
# 상품명: 미니멀 크루 넥 니트 [블랙]
# 브랜드: 무신사 스탠다드
# 가격:  59390
#
# 상품명: 클럽 레플리카 스웻셔츠 [오프 화이트]
# 브랜드: 슈퍼서브
# 가격:  39000
#
# 상품명: 폰테 크루 넥 긴팔 티셔츠 [블랙]
# 브랜드: 무신사 스탠다드
# 가격:  22390
#
# 상품명: 헤비웨이트 오버사이즈 후디드 스웨트셔츠 [블랙]
# 브랜드: 무신사 스탠다드
# 가격:  49900
#
# 상품명: 빈티지 반 집업_오트베이지
# 브랜드: 1993스튜디오
# 가격:  57600
#
# 상품명: (23SS) 2 TONE ARCH HOODIE NAVY
# 브랜드: 예일
# 가격:  55300
#
# 상품명: 에센셜 후드 스웻 셔츠 (CHARCOAL)
# 브랜드: 토피
# 가격:  39000
#
# 상품명: 하이 벤트 레이어드 티셔츠 [BLACK]
# 브랜드: 드로우핏
# 가격:  29250
#
# 상품명: 오버핏 아치 로고 스웨트 셔츠-블랙
# 브랜드: 필루미네이트
# 가격:  39900
#
# 상품명: [무료반품] 트위드 크루넥 니트웨어_아이스블루
# 브랜드: 인템포무드
# 가격:  58700
#
# 상품명: TC5-SH08 프렌치 스트라이프 셔츠-네이비
# 브랜드: 토마스모어
# 가격:  56715
#
# 상품명: 아치 팬시 로고 후드티_화이트메란지
# 브랜드: 어나더 아카이브
# 가격:  35800
#
# 상품명: 캠프 바시티 피그먼트 스웨트셔츠 블루 섀도우
# 브랜드: 트래블
# 가격:  49900
#
# 상품명: 빈티지 반 집업_라이트그레이
# 브랜드: 1993스튜디오
# 가격:  50400
#
# 상품명: 크루 넥 긴팔 티셔츠 [화이트]
# 브랜드: 무신사 스탠다드
# 가격:  19900
#
# 상품명: 로그 오버핏 기모 후드 블랙 YHHD2302
# 브랜드: 제멋
# 가격:  34900
#
# 상품명: [SS Ver.]헤비 코튼 오버 럭비 맨투맨_Black
# 브랜드: 라퍼지스토어
# 가격:  36000
#
# 상품명: ROUND LOGO CREWNECK SWEATSHIRT B...
# 브랜드: 프렌다
# 가격:  47200
#
# 상품명: [레드벨벳 웬디 PICK] [패키지] NYC LOCATIO...
# 브랜드: 그루브라임
# 가격:  69000
#
# 상품명: (23SS) [ONEMILE WEAR] SMALL ARCH...
# 브랜드: 예일
# 가격:  49000
#
# 상품명: [무료반품] 울 오버핏 라운드 니트 - 오렌지
# 브랜드: 르마드
# 가격:  68400
#
# 상품명: 코튼 워셔블 후드니트
# 브랜드: 키뮤어
# 가격:  54900
#
# 상품명: [무료반품] [니티드X깡스타일리스트] 코튼 미니멀 라운드 ...
# 브랜드: 니티드
# 가격:  59400
#
# 상품명: [논기모]나마스테 스켈레톤 후디_핑크(NG2DSUM403A...
# 브랜드: 나이스고스트클럽
# 가격:  63200
#
# 상품명: 크루넥 리브 니트 스웨터_스카이 블루
# 브랜드: 블론드나인
# 가격:  28800
#
# 상품명: 크루넥 리브 니트 스웨터_네이비
# 브랜드: 블론드나인
# 가격:  28800
#
# 상품명: (23SS) EMBROIDERY UNIVERSITY DAN...
# 브랜드: 예일
# 가격:  55300
#
# 상품명: [무료반품] 해비 코튼 썸홀 후디 : 15color
# 브랜드: 인템포무드
# 가격:  73900
#
# 상품명: 케이블 카라 니트[그린]
# 브랜드: 시그니처
# 가격:  53000
#
# 상품명: 레이어드 크루 넥 반팔 티셔츠_일반 기장 [블랙]
# 브랜드: 무신사 스탠다드
# 가격:  16900
#
# 상품명: 베츠 어센틱 맨투맨 그레이
# 브랜드: 이벳필드
# 가격:  27600
#
# 상품명: 오버핏 울 체크 셔츠 그레이
# 브랜드: 어반드레스
# 가격:  39840
#
# 상품명: 오버핏 그래피티 로고 후디-오트밀
# 브랜드: 필루미네이트
# 가격:  47900
#
# 상품명: 크루넥 리브 니트 스웨터_아이보리
# 브랜드: 블론드나인
# 가격:  28800
#
# 상품명: (23SS) 2 TONE ARCH TEE ROYAL BLU...
# 브랜드: 예일
# 가격:  35100
#
# 상품명: COLLEGE LOGO HOODIE GREY(MG2BSMM...
# 브랜드: 마하그리드
# 가격:  55200
#
# 상품명: [3PACK] 베이식 무지 레이어드 반팔 티셔츠 일반 기장...
# 브랜드: 프린트스타
# 가격:  24500
#
# 상품명: [23SS Ver.]시티보이 빅오버 옥스포드 셔츠_Roya...
# 브랜드: 라퍼지스토어
# 가격:  36800
#
# 상품명: [SET] (맨투맨 OR 후드 선택) CGP 아치 로고 트...
# 브랜드: 코드그라피
# 가격:  72900
#
# 상품명: 후디드 스웨트셔츠 [멜란지 그레이]
# 브랜드: 무신사 스탠다드
# 가격:  33990
#
# 상품명: [패키지] 로그 오버핏 기모 후드 2Pack YHHD230...
# 브랜드: 제멋
# 가격:  62500
#
# 상품명: [드로우핏X깡스타일리스트] 터틀넥 니트 티셔츠
# 브랜드: 드로우핏
# 가격:  23900
